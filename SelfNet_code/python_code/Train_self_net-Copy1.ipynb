# %%
import torch
print(torch.cuda.is_available()) 
from Supporting_functions import *

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'        
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# True

# %% [markdown]
# # Training SelfNet

# %%
# Define paths and paramters

# Models

path =r'\\WS3\WS3_Remote_Disk\Current_Segovia_lab\Deconvolution_Dilan\data\Deconvolution test\SelfNet\Microscopy\Sinusoids/'

batch_size = 10
epochs = 100

min_v = 0
max_v = 65535
pairedDataSets = False

learning_rate_G = 1e-4
learning_rate_D = 1e-4
beta1 = 0.5
beta2 = 0.999
log_interval = 500
imshow_interval = 500

input_nc = 1
output_nc = 1
        
# CUDA device
device=torch.device('cuda:0')

# Create varibale args
class TrainingArgs():
    pass

args = TrainingArgs()
args.path = path
args.batch_size = batch_size
args.epochs = epochs
args.min_v = min_v
args.max_v = max_v
args.learning_rate_G = learning_rate_G
args.learning_rate_D = learning_rate_D
args.beta1 = beta1
args.beta2 = beta2
args.log_interval = log_interval
args.imshow_interval = imshow_interval

# %%
# Create folder for output and cheking points

traning_data_path  = os.path.join(path,'train_data/train_data.npz')
checkpoint_path = os.path.join(path,'checkpoint/')

if not os.path.exists(checkpoint_path):
    os.mkdir(checkpoint_path)

model_saved_path = os.path.join(checkpoint_path,'saved_models/')
intermediate_results_path = os.path.join(checkpoint_path,'intermediate_results/')

if not os.path.exists(model_saved_path):
    os.mkdir(model_saved_path)

if not os.path.exists(intermediate_results_path):
    os.mkdir(intermediate_results_path)

# %%
# Prepare networks
netD_A = Self_net_architecture.define_D(input_nc=input_nc, ndf=64, netD='n_layers', n_layers_D=2, device=device,norm='instance')
netD_B = Self_net_architecture.define_D(input_nc=input_nc, ndf=64, netD='n_layers', n_layers_D=2, device=device,norm='instance')

netG_A = Self_net_architecture.define_G(input_nc=input_nc, output_nc=output_nc, ngf=64, netG='deblur_net', device=device,use_dropout=False,norm='instance')
netG_B = Self_net_architecture.define_G(input_nc=input_nc, output_nc=output_nc, ngf=64, netG='deblur_net', device=device,use_dropout=False,norm='instance')

deblur_net=Self_net_architecture.define_G(input_nc=input_nc, output_nc=output_nc, ngf=64, netG='deblur_net', device=device,use_dropout=False,norm='instance')

# Define loss functions
criterionGAN=Self_net_architecture.GANLoss(gan_mode='lsgan').to(device)
SSIM_loss = SSIM(data_range=1, size_average=True, win_size=11, win_sigma=1.5, channel=1)
criterionL1=L1_Charbonnier_loss()

# Optimizers
optimG = optim.Adam(itertools.chain(netG_A.parameters(), netG_B.parameters()),lr=learning_rate_G, betas=(beta1, beta2))
optimD=optim.Adam(itertools.chain(netD_A.parameters(),netD_B.parameters()),lr=learning_rate_D, betas=(beta1, beta2))
optim_deblur=optim.Adam(deblur_net.parameters(),lr=learning_rate_G, betas=(beta1, beta2))

# Training
train_set=pytorch_dataset.create_train_data(traning_data_path,batch_size,min_v,max_v, pairedDataSets)
train(train_set,netD_A,netD_B,netG_A,netG_B,deblur_net,args,device,criterionGAN,criterionL1,SSIM_loss,optimD,optimG,optim_deblur)
print('done training!')
# Out:
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# done data preprocessing!
# epoch:1,learning_rate_D:0.0001
# epoch:1,learning_rate_G:0.0001
# epochs: 1 5000/10000  degradation modeling stage: loss_D:0.250631 , loss_G: 0.802888 loss_G_cycle:0.158247 loss_feedback:0.000000
# epochs: 1 5000/10000  deblurring stage :loss_deblur:0.055804
# epochs: 1 10000/10000  degradation modeling stage: loss_D:0.228064 , loss_G: 0.742815 loss_G_cycle:0.136229 loss_feedback:0.000000
# epochs: 1 10000/10000  deblurring stage :loss_deblur:0.054459
# epoch:2,learning_rate_D:0.0001
# epoch:2,learning_rate_G:0.0001
# epochs: 2 5000/10000  degradation modeling stage: loss_D:0.227733 , loss_G: 0.698486 loss_G_cycle:0.114021 loss_feedback:0.005379
# epochs: 2 5000/10000  deblurring stage :loss_deblur:0.053975
# epochs: 2 10000/10000  degradation modeling stage: loss_D:0.235698 , loss_G: 0.653294 loss_G_cycle:0.101007 loss_feedback:0.005383
# epochs: 2 10000/10000  deblurring stage :loss_deblur:0.053981
# epoch:3,learning_rate_D:0.0001
# epoch:3,learning_rate_G:0.0001
# epochs: 3 5000/10000  degradation modeling stage: loss_D:0.232757 , loss_G: 0.654702 loss_G_cycle:0.091773 loss_feedback:0.005373
# epochs: 3 5000/10000  deblurring stage :loss_deblur:0.053883
# epochs: 3 10000/10000  degradation modeling stage: loss_D:0.224551 , loss_G: 0.684105 loss_G_cycle:0.086873 loss_feedback:0.005350
# epochs: 3 10000/10000  deblurring stage :loss_deblur:0.053616
# epoch:4,learning_rate_D:0.0001
# epoch:4,learning_rate_G:0.0001
# epochs: 4 5000/10000  degradation modeling stage: loss_D:0.221156 , loss_G: 0.694871 loss_G_cycle:0.084054 loss_feedback:0.005354
# epochs: 4 5000/10000  deblurring stage :loss_deblur:0.053658
# epochs: 4 10000/10000  degradation modeling stage: loss_D:0.221353 , loss_G: 0.709143 loss_G_cycle:0.081162 loss_feedback:0.005356
# epochs: 4 10000/10000  deblurring stage :loss_deblur:0.053659
# epoch:5,learning_rate_D:0.0001
# epoch:5,learning_rate_G:0.0001
# epochs: 5 5000/10000  degradation modeling stage: loss_D:0.241289 , loss_G: 0.829204 loss_G_cycle:0.096561 loss_feedback:0.005452
# epochs: 5 5000/10000  deblurring stage :loss_deblur:0.054834
# epochs: 5 10000/10000  degradation modeling stage: loss_D:0.191195 , loss_G: 0.798316 loss_G_cycle:0.087757 loss_feedback:0.005434
# epochs: 5 10000/10000  deblurring stage :loss_deblur:0.054476
# epoch:6,learning_rate_D:0.0001
# epoch:6,learning_rate_G:0.0001
# epochs: 6 5000/10000  degradation modeling stage: loss_D:0.176199 , loss_G: 0.870900 loss_G_cycle:0.083774 loss_feedback:0.005394
# epochs: 6 5000/10000  deblurring stage :loss_deblur:0.054062
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 22
#      20 # Training
#      21 train_set=pytorch_dataset.create_train_data(traning_data_path,batch_size,min_v,max_v, pairedDataSets)
# ---> 22 train(train_set,netD_A,netD_B,netG_A,netG_B,deblur_net,args,device,criterionGAN,criterionL1,SSIM_loss,optimD,optimG,optim_deblur)
#      23 print('done training!')
#
# File C:\Selfnet\Python_code\Supporting_functions.py:150, in train(train_set, netD_A, netD_B, netG_A, netG_B, deblur_net, args, device, criterionGAN, criterionL1, SSIM_loss, optimD, optimG, optim_deblur)
#     144 loss_G_B = lambda_gan*criterionGAN(netD_B(fake_A), True)
#     147 # Forward cycle loss || G_B(G_A(A)) - A||
# --> 150 loss_cycle_A = lambda_cycle*criterionL1(rec_A,A)+lambda_ssim*(1-SSIM_loss(rec_A,A))
#     152 # Backward cycle loss || G_A(G_B(B)) - B||
#     154 loss_cycle_B = lambda_cycle*criterionL1(rec_B,B)+lambda_ssim*(1-SSIM_loss(rec_B,B))
#
# File ~\anaconda3\envs\selfnet\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\selfnet\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File C:\Selfnet\Python_code\ssim.py:238, in SSIM.forward(self, X, Y)
#     237 def forward(self, X, Y):
# --> 238     return ssim(X, Y,
#     239                 data_range=self.data_range,
#     240                 size_average=self.size_average,
#     241                 win=self.win,
#     242                 K=self.K,
#     243                 nonnegative_ssim=self.nonnegative_ssim)
#
# File C:\Selfnet\Python_code\ssim.py:121, in ssim(X, Y, data_range, size_average, win_size, win_sigma, win, K, nonnegative_ssim)
#     118     win = _fspecial_gauss_1d(win_size, win_sigma)
#     119     win = win.repeat(X.shape[1], 1, 1, 1)
# --> 121 ssim_per_channel, cs = _ssim(X, Y,
#     122                              data_range=data_range,
#     123                              win=win,
#     124                              size_average=False,
#     125                              K=K)
#     126 if nonnegative_ssim:
#     127     ssim_per_channel = torch.relu(ssim_per_channel)
#
# File C:\Selfnet\Python_code\ssim.py:58, in _ssim(X, Y, data_range, win, size_average, K)
#      55 C1 = (K1 * data_range) ** 2
#      56 C2 = (K2 * data_range) ** 2
# ---> 58 win = win.to(X.device, dtype=X.dtype)
#      60 mu1 = gaussian_filter(X, win)
#      61 mu2 = gaussian_filter(Y, win)
#
# KeyboardInterrupt:
# epochs: 49 9600/10176  degradation modeling stage: loss_D:0.130386 , loss_G: 1.102520 loss_G_cycle:0.082676 loss_feedback:0.003962
# epochs: 49 9600/10176  deblurring stage :loss_deblur:0.039649
# epoch:50,learning_rate_D:1.25e-05
# epoch:50,learning_rate_G:1.25e-05
# epochs: 50 800/10176  degradation modeling stage: loss_D:0.262444 , loss_G: 1.753373 loss_G_cycle:0.144459 loss_feedback:0.006877
# epochs: 50 800/10176  deblurring stage :loss_deblur:0.068858
# epochs: 50 1600/10176  degradation modeling stage: loss_D:0.135915 , loss_G: 1.083854 loss_G_cycle:0.083900 loss_feedback:0.003971
# epochs: 50 1600/10176  deblurring stage :loss_deblur:0.039757
# epochs: 50 2400/10176  degradation modeling stage: loss_D:0.129708 , loss_G: 1.097620 loss_G_cycle:0.083559 loss_feedback:0.003950
# epochs: 50 2400/10176  deblurring stage :loss_deblur:0.039577
# epochs: 50 3200/10176  degradation modeling stage: loss_D:0.165819 , loss_G: 0.914218 loss_G_cycle:0.083746 loss_feedback:0.004010
# epochs: 50 3200/10176  deblurring stage :loss_deblur:0.040144
# epochs: 50 4000/10176  degradation modeling stage: loss_D:0.136265 , loss_G: 1.074686 loss_G_cycle:0.082814 loss_feedback:0.003991
# epochs: 50 4000/10176  deblurring stage :loss_deblur:0.039970
# epochs: 50 4800/10176  degradation modeling stage: loss_D:0.132481 , loss_G: 1.073798 loss_G_cycle:0.082494 loss_feedback:0.003950
# epochs: 50 4800/10176  deblurring stage :loss_deblur:0.039539
# epochs: 50 5600/10176  degradation modeling stage: loss_D:0.156856 , loss_G: 0.977374 loss_G_cycle:0.084823 loss_feedback:0.004015
# epochs: 50 5600/10176  deblurring stage :loss_deblur:0.040217
# epochs: 50 6400/10176  degradation modeling stage: loss_D:0.138411 , loss_G: 1.064572 loss_G_cycle:0.083266 loss_feedback:0.003969
# epochs: 50 6400/10176  deblurring stage :loss_deblur:0.039728
# epochs: 50 7200/10176  degradation modeling stage: loss_D:0.132212 , loss_G: 1.100027 loss_G_cycle:0.083500 loss_feedback:0.003968
# epochs: 50 7200/10176  deblurring stage :loss_deblur:0.039743
# epochs: 50 8000/10176  degradation modeling stage: loss_D:0.163853 , loss_G: 0.947318 loss_G_cycle:0.083765 loss_feedback:0.004021
# epochs: 50 8000/10176  deblurring stage :loss_deblur:0.040276
# epochs: 50 8800/10176  degradation modeling stage: loss_D:0.137114 , loss_G: 1.048911 loss_G_cycle:0.082682 loss_feedback:0.003962
# epochs: 50 8800/10176  deblurring stage :loss_deblur:0.039660
# epochs: 50 9600/10176  degradation modeling stage: loss_D:0.132842 , loss_G: 1.087415 loss_G_cycle:0.083284 loss_feedback:0.003968
# epochs: 50 9600/10176  deblurring stage :loss_deblur:0.039726
# epoch:51,learning_rate_D:1.25e-05
# epoch:51,learning_rate_G:1.25e-05
# epochs: 51 800/10176  degradation modeling stage: loss_D:0.219915 , loss_G: 1.913906 loss_G_cycle:0.142286 loss_feedback:0.006802
# epochs: 51 800/10176  deblurring stage :loss_deblur:0.068098
# epochs: 51 1600/10176  degradation modeling stage: loss_D:0.136593 , loss_G: 1.074828 loss_G_cycle:0.082966 loss_feedback:0.003992
# epochs: 51 1600/10176  deblurring stage :loss_deblur:0.039990
# epochs: 51 2400/10176  degradation modeling stage: loss_D:0.160932 , loss_G: 0.985085 loss_G_cycle:0.083664 loss_feedback:0.003997
# epochs: 51 2400/10176  deblurring stage :loss_deblur:0.040006
# epochs: 51 3200/10176  degradation modeling stage: loss_D:0.149404 , loss_G: 1.007154 loss_G_cycle:0.082987 loss_feedback:0.003985
# epochs: 51 3200/10176  deblurring stage :loss_deblur:0.039923
# epochs: 51 4000/10176  degradation modeling stage: loss_D:0.143143 , loss_G: 1.021943 loss_G_cycle:0.083417 loss_feedback:0.004006
# epochs: 51 4000/10176  deblurring stage :loss_deblur:0.040090
# epochs: 51 4800/10176  degradation modeling stage: loss_D:0.154988 , loss_G: 1.005849 loss_G_cycle:0.083884 loss_feedback:0.003996
# epochs: 51 4800/10176  deblurring stage :loss_deblur:0.040025
# epochs: 51 5600/10176  degradation modeling stage: loss_D:0.140068 , loss_G: 1.044531 loss_G_cycle:0.083352 loss_feedback:0.003973
# epochs: 51 5600/10176  deblurring stage :loss_deblur:0.039789
# epochs: 51 6400/10176  degradation modeling stage: loss_D:0.151271 , loss_G: 0.989566 loss_G_cycle:0.083757 loss_feedback:0.003990
# epochs: 51 6400/10176  deblurring stage :loss_deblur:0.039971
# epochs: 51 7200/10176  degradation modeling stage: loss_D:0.143600 , loss_G: 1.012541 loss_G_cycle:0.082932 loss_feedback:0.003950
# epochs: 51 7200/10176  deblurring stage :loss_deblur:0.039535
# epochs: 51 8000/10176  degradation modeling stage: loss_D:0.159794 , loss_G: 0.990412 loss_G_cycle:0.084195 loss_feedback:0.004011
# epochs: 51 8000/10176  deblurring stage :loss_deblur:0.040192
# epochs: 51 8800/10176  degradation modeling stage: loss_D:0.137417 , loss_G: 1.082891 loss_G_cycle:0.083515 loss_feedback:0.003979
# epochs: 51 8800/10176  deblurring stage :loss_deblur:0.039839
# epochs: 51 9600/10176  degradation modeling stage: loss_D:0.155994 , loss_G: 0.982049 loss_G_cycle:0.083770 loss_feedback:0.004000
# epochs: 51 9600/10176  deblurring stage :loss_deblur:0.040058
# epoch:52,learning_rate_D:1.25e-05
# epoch:52,learning_rate_G:1.25e-05
# epochs: 52 800/10176  degradation modeling stage: loss_D:0.254092 , loss_G: 1.729043 loss_G_cycle:0.143518 loss_feedback:0.006859
# epochs: 52 800/10176  deblurring stage :loss_deblur:0.068698
# epochs: 52 1600/10176  degradation modeling stage: loss_D:0.142518 , loss_G: 1.043472 loss_G_cycle:0.083283 loss_feedback:0.003981
# epochs: 52 1600/10176  deblurring stage :loss_deblur:0.039856
# epochs: 52 2400/10176  degradation modeling stage: loss_D:0.142411 , loss_G: 1.039047 loss_G_cycle:0.083903 loss_feedback:0.003996
# epochs: 52 2400/10176  deblurring stage :loss_deblur:0.040045
# epochs: 52 3200/10176  degradation modeling stage: loss_D:0.144232 , loss_G: 0.999306 loss_G_cycle:0.083073 loss_feedback:0.003974
# epochs: 52 3200/10176  deblurring stage :loss_deblur:0.039779
# epochs: 52 4000/10176  degradation modeling stage: loss_D:0.158256 , loss_G: 0.980322 loss_G_cycle:0.083885 loss_feedback:0.003991
# epochs: 52 4000/10176  deblurring stage :loss_deblur:0.039987
# epochs: 52 4800/10176  degradation modeling stage: loss_D:0.134318 , loss_G: 1.072756 loss_G_cycle:0.083308 loss_feedback:0.003976
# epochs: 52 4800/10176  deblurring stage :loss_deblur:0.039843
# epochs: 52 5600/10176  degradation modeling stage: loss_D:0.133914 , loss_G: 1.071703 loss_G_cycle:0.083313 loss_feedback:0.003953
# epochs: 52 5600/10176  deblurring stage :loss_deblur:0.039568
# epochs: 52 6400/10176  degradation modeling stage: loss_D:0.152903 , loss_G: 1.000317 loss_G_cycle:0.083899 loss_feedback:0.004010
# epochs: 52 6400/10176  deblurring stage :loss_deblur:0.040181
# epochs: 52 7200/10176  degradation modeling stage: loss_D:0.146723 , loss_G: 1.009527 loss_G_cycle:0.083054 loss_feedback:0.004002
# epochs: 52 7200/10176  deblurring stage :loss_deblur:0.040064
# epochs: 52 8000/10176  degradation modeling stage: loss_D:0.146032 , loss_G: 1.022642 loss_G_cycle:0.083768 loss_feedback:0.003976
# epochs: 52 8000/10176  deblurring stage :loss_deblur:0.039825
# epochs: 52 8800/10176  degradation modeling stage: loss_D:0.147468 , loss_G: 1.036714 loss_G_cycle:0.083757 loss_feedback:0.004005
# epochs: 52 8800/10176  deblurring stage :loss_deblur:0.040101
# epochs: 52 9600/10176  degradation modeling stage: loss_D:0.135295 , loss_G: 1.094428 loss_G_cycle:0.083504 loss_feedback:0.003970
# epochs: 52 9600/10176  deblurring stage :loss_deblur:0.039761
# epoch:53,learning_rate_D:1.25e-05
# epoch:53,learning_rate_G:1.25e-05
# epochs: 53 800/10176  degradation modeling stage: loss_D:0.222313 , loss_G: 1.908761 loss_G_cycle:0.143579 loss_feedback:0.006834
# epochs: 53 800/10176  deblurring stage :loss_deblur:0.068440
# epochs: 53 1600/10176  degradation modeling stage: loss_D:0.168742 , loss_G: 0.919026 loss_G_cycle:0.083951 loss_feedback:0.004033
# epochs: 53 1600/10176  deblurring stage :loss_deblur:0.040364
# epochs: 53 2400/10176  degradation modeling stage: loss_D:0.132832 , loss_G: 1.059964 loss_G_cycle:0.082966 loss_feedback:0.003950
# epochs: 53 2400/10176  deblurring stage :loss_deblur:0.039555
# epochs: 53 3200/10176  degradation modeling stage: loss_D:0.132958 , loss_G: 1.086848 loss_G_cycle:0.083400 loss_feedback:0.003991
# epochs: 53 3200/10176  deblurring stage :loss_deblur:0.039945
# epochs: 53 4000/10176  degradation modeling stage: loss_D:0.152202 , loss_G: 1.011176 loss_G_cycle:0.083617 loss_feedback:0.004014
# epochs: 53 4000/10176  deblurring stage :loss_deblur:0.040230
# epochs: 53 4800/10176  degradation modeling stage: loss_D:0.143762 , loss_G: 1.057730 loss_G_cycle:0.083655 loss_feedback:0.003974
# epochs: 53 4800/10176  deblurring stage :loss_deblur:0.039818
# epochs: 53 5600/10176  degradation modeling stage: loss_D:0.130040 , loss_G: 1.117006 loss_G_cycle:0.083546 loss_feedback:0.003959
# epochs: 53 5600/10176  deblurring stage :loss_deblur:0.039678
# epochs: 53 6400/10176  degradation modeling stage: loss_D:0.159501 , loss_G: 0.963114 loss_G_cycle:0.084030 loss_feedback:0.004022
# epochs: 53 6400/10176  deblurring stage :loss_deblur:0.040279
# epochs: 53 7200/10176  degradation modeling stage: loss_D:0.132964 , loss_G: 1.074699 loss_G_cycle:0.083217 loss_feedback:0.004002
# epochs: 53 7200/10176  deblurring stage :loss_deblur:0.040068
# epochs: 53 8000/10176  degradation modeling stage: loss_D:0.154439 , loss_G: 0.994032 loss_G_cycle:0.083927 loss_feedback:0.004000
# epochs: 53 8000/10176  deblurring stage :loss_deblur:0.040075
# epochs: 53 8800/10176  degradation modeling stage: loss_D:0.135869 , loss_G: 1.069375 loss_G_cycle:0.083738 loss_feedback:0.003963
# epochs: 53 8800/10176  deblurring stage :loss_deblur:0.039688
# epochs: 53 9600/10176  degradation modeling stage: loss_D:0.155481 , loss_G: 0.974246 loss_G_cycle:0.083810 loss_feedback:0.004000
# epochs: 53 9600/10176  deblurring stage :loss_deblur:0.040048
# epoch:54,learning_rate_D:1.25e-05
# epoch:54,learning_rate_G:1.25e-05
# epochs: 54 800/10176  degradation modeling stage: loss_D:0.256377 , loss_G: 1.731070 loss_G_cycle:0.143622 loss_feedback:0.006858
# epochs: 54 800/10176  deblurring stage :loss_deblur:0.068665
# epochs: 54 1600/10176  degradation modeling stage: loss_D:0.144234 , loss_G: 1.034545 loss_G_cycle:0.083790 loss_feedback:0.003999
# epochs: 54 1600/10176  deblurring stage :loss_deblur:0.040041
# epochs: 54 2400/10176  degradation modeling stage: loss_D:0.154487 , loss_G: 1.005597 loss_G_cycle:0.084031 loss_feedback:0.004016
# epochs: 54 2400/10176  deblurring stage :loss_deblur:0.040245
# epochs: 54 3200/10176  degradation modeling stage: loss_D:0.147872 , loss_G: 1.010368 loss_G_cycle:0.082784 loss_feedback:0.003963
# epochs: 54 3200/10176  deblurring stage :loss_deblur:0.039659
# epochs: 54 4000/10176  degradation modeling stage: loss_D:0.157877 , loss_G: 0.979734 loss_G_cycle:0.084038 loss_feedback:0.003962
# epochs: 54 4000/10176  deblurring stage :loss_deblur:0.039674
# epochs: 54 4800/10176  degradation modeling stage: loss_D:0.137959 , loss_G: 1.066702 loss_G_cycle:0.083457 loss_feedback:0.003965
# epochs: 54 4800/10176  deblurring stage :loss_deblur:0.039717
# epochs: 54 5600/10176  degradation modeling stage: loss_D:0.154895 , loss_G: 0.968140 loss_G_cycle:0.083963 loss_feedback:0.004014
# epochs: 54 5600/10176  deblurring stage :loss_deblur:0.040215
# epochs: 54 6400/10176  degradation modeling stage: loss_D:0.141289 , loss_G: 1.045542 loss_G_cycle:0.083322 loss_feedback:0.003984
# epochs: 54 6400/10176  deblurring stage :loss_deblur:0.039886
# epochs: 54 7200/10176  degradation modeling stage: loss_D:0.159386 , loss_G: 0.995521 loss_G_cycle:0.084598 loss_feedback:0.004001
# epochs: 54 7200/10176  deblurring stage :loss_deblur:0.040085
# epochs: 54 8000/10176  degradation modeling stage: loss_D:0.138092 , loss_G: 1.068722 loss_G_cycle:0.083442 loss_feedback:0.003977
# epochs: 54 8000/10176  deblurring stage :loss_deblur:0.039807
# epochs: 54 8800/10176  degradation modeling stage: loss_D:0.156096 , loss_G: 0.983431 loss_G_cycle:0.083655 loss_feedback:0.004011
# epochs: 54 8800/10176  deblurring stage :loss_deblur:0.040198
# epochs: 54 9600/10176  degradation modeling stage: loss_D:0.140755 , loss_G: 1.034768 loss_G_cycle:0.083194 loss_feedback:0.003988
# epochs: 54 9600/10176  deblurring stage :loss_deblur:0.039922
# epoch:55,learning_rate_D:1.25e-05
# epoch:55,learning_rate_G:1.25e-05
# epochs: 55 800/10176  degradation modeling stage: loss_D:0.258878 , loss_G: 1.720011 loss_G_cycle:0.144469 loss_feedback:0.006904
# epochs: 55 800/10176  deblurring stage :loss_deblur:0.069188
# epochs: 55 1600/10176  degradation modeling stage: loss_D:0.159717 , loss_G: 0.965938 loss_G_cycle:0.084235 loss_feedback:0.004038
# epochs: 55 1600/10176  deblurring stage :loss_deblur:0.040401
# epochs: 55 2400/10176  degradation modeling stage: loss_D:0.145883 , loss_G: 1.022964 loss_G_cycle:0.083330 loss_feedback:0.003982
# epochs: 55 2400/10176  deblurring stage :loss_deblur:0.039897
# epochs: 55 3200/10176  degradation modeling stage: loss_D:0.149671 , loss_G: 1.031163 loss_G_cycle:0.083905 loss_feedback:0.003980
# epochs: 55 3200/10176  deblurring stage :loss_deblur:0.039846
# epochs: 55 4000/10176  degradation modeling stage: loss_D:0.133370 , loss_G: 1.085377 loss_G_cycle:0.083431 loss_feedback:0.003957
# epochs: 55 4000/10176  deblurring stage :loss_deblur:0.039627
# epochs: 55 4800/10176  degradation modeling stage: loss_D:0.158417 , loss_G: 0.978720 loss_G_cycle:0.084324 loss_feedback:0.004009
# epochs: 55 4800/10176  deblurring stage :loss_deblur:0.040169
# epochs: 55 5600/10176  degradation modeling stage: loss_D:0.142289 , loss_G: 1.024604 loss_G_cycle:0.084001 loss_feedback:0.004014
# epochs: 55 5600/10176  deblurring stage :loss_deblur:0.040226
# epochs: 55 6400/10176  degradation modeling stage: loss_D:0.154640 , loss_G: 1.009201 loss_G_cycle:0.083823 loss_feedback:0.003990
# epochs: 55 6400/10176  deblurring stage :loss_deblur:0.039979
# epochs: 55 7200/10176  degradation modeling stage: loss_D:0.132238 , loss_G: 1.085242 loss_G_cycle:0.083870 loss_feedback:0.003979
# epochs: 55 7200/10176  deblurring stage :loss_deblur:0.039900
# epochs: 55 8000/10176  degradation modeling stage: loss_D:0.161911 , loss_G: 0.947990 loss_G_cycle:0.084175 loss_feedback:0.004017
# epochs: 55 8000/10176  deblurring stage :loss_deblur:0.040203
# epochs: 55 8800/10176  degradation modeling stage: loss_D:0.133236 , loss_G: 1.082317 loss_G_cycle:0.083076 loss_feedback:0.003976
# epochs: 55 8800/10176  deblurring stage :loss_deblur:0.039802
# epochs: 55 9600/10176  degradation modeling stage: loss_D:0.158359 , loss_G: 0.997460 loss_G_cycle:0.084067 loss_feedback:0.003998
# epochs: 55 9600/10176  deblurring stage :loss_deblur:0.040063
# epoch:56,learning_rate_D:1.25e-05
# epoch:56,learning_rate_G:1.25e-05
# epochs: 56 800/10176  degradation modeling stage: loss_D:0.252796 , loss_G: 1.766811 loss_G_cycle:0.143968 loss_feedback:0.006891
# epochs: 56 800/10176  deblurring stage :loss_deblur:0.069007
# epochs: 56 1600/10176  degradation modeling stage: loss_D:0.149391 , loss_G: 1.000402 loss_G_cycle:0.083523 loss_feedback:0.003987
# epochs: 56 1600/10176  deblurring stage :loss_deblur:0.039931
# epochs: 56 2400/10176  degradation modeling stage: loss_D:0.156380 , loss_G: 0.987301 loss_G_cycle:0.084108 loss_feedback:0.003987
# epochs: 56 2400/10176  deblurring stage :loss_deblur:0.039918
# epochs: 56 3200/10176  degradation modeling stage: loss_D:0.151710 , loss_G: 1.021844 loss_G_cycle:0.083964 loss_feedback:0.004015
# epochs: 56 3200/10176  deblurring stage :loss_deblur:0.040222
# epochs: 56 4000/10176  degradation modeling stage: loss_D:0.149227 , loss_G: 1.006967 loss_G_cycle:0.083366 loss_feedback:0.004006
# epochs: 56 4000/10176  deblurring stage :loss_deblur:0.040085
# epochs: 56 4800/10176  degradation modeling stage: loss_D:0.147385 , loss_G: 1.013560 loss_G_cycle:0.084089 loss_feedback:0.004019
# epochs: 56 4800/10176  deblurring stage :loss_deblur:0.040248
# epochs: 56 5600/10176  degradation modeling stage: loss_D:0.148674 , loss_G: 1.024972 loss_G_cycle:0.083494 loss_feedback:0.003973
# epochs: 56 5600/10176  deblurring stage :loss_deblur:0.039787
# epochs: 56 6400/10176  degradation modeling stage: loss_D:0.155153 , loss_G: 0.992390 loss_G_cycle:0.084499 loss_feedback:0.004033
# epochs: 56 6400/10176  deblurring stage :loss_deblur:0.040402
# epochs: 56 7200/10176  degradation modeling stage: loss_D:0.143432 , loss_G: 1.025935 loss_G_cycle:0.083154 loss_feedback:0.003966
# epochs: 56 7200/10176  deblurring stage :loss_deblur:0.039700
# epochs: 56 8000/10176  degradation modeling stage: loss_D:0.155931 , loss_G: 0.981660 loss_G_cycle:0.084280 loss_feedback:0.004014
# epochs: 56 8000/10176  deblurring stage :loss_deblur:0.040215
# epochs: 56 8800/10176  degradation modeling stage: loss_D:0.138553 , loss_G: 1.059716 loss_G_cycle:0.083678 loss_feedback:0.003965
# epochs: 56 8800/10176  deblurring stage :loss_deblur:0.039707
# epochs: 56 9600/10176  degradation modeling stage: loss_D:0.147982 , loss_G: 1.017929 loss_G_cycle:0.083848 loss_feedback:0.003994
# epochs: 56 9600/10176  deblurring stage :loss_deblur:0.039996
# epoch:57,learning_rate_D:1.25e-05
# epoch:57,learning_rate_G:1.25e-05
# epochs: 57 800/10176  degradation modeling stage: loss_D:0.264659 , loss_G: 1.699006 loss_G_cycle:0.144434 loss_feedback:0.006872
# epochs: 57 800/10176  deblurring stage :loss_deblur:0.068798
# epochs: 57 1600/10176  degradation modeling stage: loss_D:0.140315 , loss_G: 1.060564 loss_G_cycle:0.083214 loss_feedback:0.003964
# epochs: 57 1600/10176  deblurring stage :loss_deblur:0.039722
# epochs: 57 2400/10176  degradation modeling stage: loss_D:0.157720 , loss_G: 0.981446 loss_G_cycle:0.084099 loss_feedback:0.004034
# epochs: 57 2400/10176  deblurring stage :loss_deblur:0.040377
# epochs: 57 3200/10176  degradation modeling stage: loss_D:0.132347 , loss_G: 1.089149 loss_G_cycle:0.082957 loss_feedback:0.003977
# epochs: 57 3200/10176  deblurring stage :loss_deblur:0.039812
# epochs: 57 4000/10176  degradation modeling stage: loss_D:0.125586 , loss_G: 1.118971 loss_G_cycle:0.082854 loss_feedback:0.003973
# epochs: 57 4000/10176  deblurring stage :loss_deblur:0.039769
# epochs: 57 4800/10176  degradation modeling stage: loss_D:0.153631 , loss_G: 1.022164 loss_G_cycle:0.084034 loss_feedback:0.004017
# epochs: 57 4800/10176  deblurring stage :loss_deblur:0.040268
# epochs: 57 5600/10176  degradation modeling stage: loss_D:0.143505 , loss_G: 1.060324 loss_G_cycle:0.083432 loss_feedback:0.003972
# epochs: 57 5600/10176  deblurring stage :loss_deblur:0.039782
# epochs: 57 6400/10176  degradation modeling stage: loss_D:0.157794 , loss_G: 0.986684 loss_G_cycle:0.084124 loss_feedback:0.004038
# epochs: 57 6400/10176  deblurring stage :loss_deblur:0.040469
# epochs: 57 7200/10176  degradation modeling stage: loss_D:0.131236 , loss_G: 1.088046 loss_G_cycle:0.083087 loss_feedback:0.003974
# epochs: 57 7200/10176  deblurring stage :loss_deblur:0.039813
# epochs: 57 8000/10176  degradation modeling stage: loss_D:0.162046 , loss_G: 0.975583 loss_G_cycle:0.084337 loss_feedback:0.003988
# epochs: 57 8000/10176  deblurring stage :loss_deblur:0.039923
# epochs: 57 8800/10176  degradation modeling stage: loss_D:0.151033 , loss_G: 1.019137 loss_G_cycle:0.084111 loss_feedback:0.003998
# epochs: 57 8800/10176  deblurring stage :loss_deblur:0.040061
# epochs: 57 9600/10176  degradation modeling stage: loss_D:0.144429 , loss_G: 1.022483 loss_G_cycle:0.083377 loss_feedback:0.003992
# epochs: 57 9600/10176  deblurring stage :loss_deblur:0.039958
# epoch:58,learning_rate_D:1.25e-05
# epoch:58,learning_rate_G:1.25e-05
# epochs: 58 800/10176  degradation modeling stage: loss_D:0.258205 , loss_G: 1.739005 loss_G_cycle:0.143948 loss_feedback:0.006859
# epochs: 58 800/10176  deblurring stage :loss_deblur:0.068740
# epochs: 58 1600/10176  degradation modeling stage: loss_D:0.145934 , loss_G: 1.039254 loss_G_cycle:0.084067 loss_feedback:0.004012
# epochs: 58 1600/10176  deblurring stage :loss_deblur:0.040183
# epochs: 58 2400/10176  degradation modeling stage: loss_D:0.152399 , loss_G: 0.994469 loss_G_cycle:0.083785 loss_feedback:0.004002
# epochs: 58 2400/10176  deblurring stage :loss_deblur:0.040066
# epochs: 58 3200/10176  degradation modeling stage: loss_D:0.134751 , loss_G: 1.075242 loss_G_cycle:0.083051 loss_feedback:0.003955
# epochs: 58 3200/10176  deblurring stage :loss_deblur:0.039574
# epochs: 58 4000/10176  degradation modeling stage: loss_D:0.157204 , loss_G: 0.981675 loss_G_cycle:0.084193 loss_feedback:0.003985
# epochs: 58 4000/10176  deblurring stage :loss_deblur:0.039921
# epochs: 58 4800/10176  degradation modeling stage: loss_D:0.140850 , loss_G: 1.073195 loss_G_cycle:0.083291 loss_feedback:0.003992
# epochs: 58 4800/10176  deblurring stage :loss_deblur:0.039973
# epochs: 58 5600/10176  degradation modeling stage: loss_D:0.152429 , loss_G: 1.005249 loss_G_cycle:0.084046 loss_feedback:0.004000
# epochs: 58 5600/10176  deblurring stage :loss_deblur:0.040074
# epochs: 58 6400/10176  degradation modeling stage: loss_D:0.145996 , loss_G: 1.019758 loss_G_cycle:0.083869 loss_feedback:0.003999
# epochs: 58 6400/10176  deblurring stage :loss_deblur:0.040050
# epochs: 58 7200/10176  degradation modeling stage: loss_D:0.149216 , loss_G: 1.009863 loss_G_cycle:0.083465 loss_feedback:0.003960
# epochs: 58 7200/10176  deblurring stage :loss_deblur:0.039650
# epochs: 58 8000/10176  degradation modeling stage: loss_D:0.158530 , loss_G: 0.983809 loss_G_cycle:0.083961 loss_feedback:0.004013
# epochs: 58 8000/10176  deblurring stage :loss_deblur:0.040193
# epochs: 58 8800/10176  degradation modeling stage: loss_D:0.138510 , loss_G: 1.058945 loss_G_cycle:0.083017 loss_feedback:0.003975
# epochs: 58 8800/10176  deblurring stage :loss_deblur:0.039774
# epochs: 58 9600/10176  degradation modeling stage: loss_D:0.152968 , loss_G: 1.005348 loss_G_cycle:0.083587 loss_feedback:0.003987
# epochs: 58 9600/10176  deblurring stage :loss_deblur:0.039927
# epoch:59,learning_rate_D:1.25e-05
# epoch:59,learning_rate_G:1.25e-05
# epochs: 59 800/10176  degradation modeling stage: loss_D:0.257960 , loss_G: 1.745205 loss_G_cycle:0.144624 loss_feedback:0.006880
# epochs: 59 800/10176  deblurring stage :loss_deblur:0.068957
# epochs: 59 1600/10176  degradation modeling stage: loss_D:0.145151 , loss_G: 1.033480 loss_G_cycle:0.083475 loss_feedback:0.003984
# epochs: 59 1600/10176  deblurring stage :loss_deblur:0.039883
# epochs: 59 2400/10176  degradation modeling stage: loss_D:0.154547 , loss_G: 0.995614 loss_G_cycle:0.083202 loss_feedback:0.003974
# epochs: 59 2400/10176  deblurring stage :loss_deblur:0.039799
# epochs: 59 3200/10176  degradation modeling stage: loss_D:0.139548 , loss_G: 1.057870 loss_G_cycle:0.083331 loss_feedback:0.003964
# epochs: 59 3200/10176  deblurring stage :loss_deblur:0.039705
# epochs: 59 4000/10176  degradation modeling stage: loss_D:0.156939 , loss_G: 0.987438 loss_G_cycle:0.084008 loss_feedback:0.004020
# epochs: 59 4000/10176  deblurring stage :loss_deblur:0.040265
# epochs: 59 4800/10176  degradation modeling stage: loss_D:0.148329 , loss_G: 1.007339 loss_G_cycle:0.083522 loss_feedback:0.003985
# epochs: 59 4800/10176  deblurring stage :loss_deblur:0.039920
# epochs: 59 5600/10176  degradation modeling stage: loss_D:0.149456 , loss_G: 1.014634 loss_G_cycle:0.083674 loss_feedback:0.003956
# epochs: 59 5600/10176  deblurring stage :loss_deblur:0.039631
# epochs: 59 6400/10176  degradation modeling stage: loss_D:0.139612 , loss_G: 1.052173 loss_G_cycle:0.083976 loss_feedback:0.004002
# epochs: 59 6400/10176  deblurring stage :loss_deblur:0.040106
# epochs: 59 7200/10176  degradation modeling stage: loss_D:0.151749 , loss_G: 0.998535 loss_G_cycle:0.083729 loss_feedback:0.003997
# epochs: 59 7200/10176  deblurring stage :loss_deblur:0.040029
# epochs: 59 8000/10176  degradation modeling stage: loss_D:0.157289 , loss_G: 0.972934 loss_G_cycle:0.084539 loss_feedback:0.004021
# epochs: 59 8000/10176  deblurring stage :loss_deblur:0.040275
# epochs: 59 8800/10176  degradation modeling stage: loss_D:0.142455 , loss_G: 1.038295 loss_G_cycle:0.082647 loss_feedback:0.003927
# epochs: 59 8800/10176  deblurring stage :loss_deblur:0.039320
# epochs: 59 9600/10176  degradation modeling stage: loss_D:0.160961 , loss_G: 0.970509 loss_G_cycle:0.083606 loss_feedback:0.004006
# epochs: 59 9600/10176  deblurring stage :loss_deblur:0.040125
# epoch:60,learning_rate_D:6.25e-06
# epoch:60,learning_rate_G:6.25e-06
# epochs: 60 800/10176  degradation modeling stage: loss_D:0.226790 , loss_G: 1.861952 loss_G_cycle:0.142213 loss_feedback:0.006806
# epochs: 60 800/10176  deblurring stage :loss_deblur:0.068120
# epochs: 60 1600/10176  degradation modeling stage: loss_D:0.170402 , loss_G: 0.938714 loss_G_cycle:0.084259 loss_feedback:0.003980
# epochs: 60 1600/10176  deblurring stage :loss_deblur:0.039809
# epochs: 60 2400/10176  degradation modeling stage: loss_D:0.139514 , loss_G: 1.055605 loss_G_cycle:0.083472 loss_feedback:0.003965
# epochs: 60 2400/10176  deblurring stage :loss_deblur:0.039662
# epochs: 60 3200/10176  degradation modeling stage: loss_D:0.141859 , loss_G: 1.063464 loss_G_cycle:0.083092 loss_feedback:0.004002
# epochs: 60 3200/10176  deblurring stage :loss_deblur:0.040049
# epochs: 60 4000/10176  degradation modeling stage: loss_D:0.152006 , loss_G: 1.012245 loss_G_cycle:0.083949 loss_feedback:0.003989
# epochs: 60 4000/10176  deblurring stage :loss_deblur:0.039908
# epochs: 60 4800/10176  degradation modeling stage: loss_D:0.133361 , loss_G: 1.064417 loss_G_cycle:0.082697 loss_feedback:0.003970
# epochs: 60 4800/10176  deblurring stage :loss_deblur:0.039720
# epochs: 60 5600/10176  degradation modeling stage: loss_D:0.129203 , loss_G: 1.093286 loss_G_cycle:0.083239 loss_feedback:0.003990
# epochs: 60 5600/10176  deblurring stage :loss_deblur:0.039920
# epochs: 60 6400/10176  degradation modeling stage: loss_D:0.127903 , loss_G: 1.117770 loss_G_cycle:0.082497 loss_feedback:0.003985
# epochs: 60 6400/10176  deblurring stage :loss_deblur:0.039872
# epochs: 60 7200/10176  degradation modeling stage: loss_D:0.171094 , loss_G: 0.937081 loss_G_cycle:0.084439 loss_feedback:0.004002
# epochs: 60 7200/10176  deblurring stage :loss_deblur:0.040040
# epochs: 60 8000/10176  degradation modeling stage: loss_D:0.138528 , loss_G: 1.071603 loss_G_cycle:0.083110 loss_feedback:0.003987
# epochs: 60 8000/10176  deblurring stage :loss_deblur:0.039884
# epochs: 60 8800/10176  degradation modeling stage: loss_D:0.130253 , loss_G: 1.114324 loss_G_cycle:0.082631 loss_feedback:0.003936
# epochs: 60 8800/10176  deblurring stage :loss_deblur:0.039370
# epochs: 60 9600/10176  degradation modeling stage: loss_D:0.149961 , loss_G: 1.019583 loss_G_cycle:0.083900 loss_feedback:0.003998
# epochs: 60 9600/10176  deblurring stage :loss_deblur:0.040012
# epoch:61,learning_rate_D:6.25e-06
# epoch:61,learning_rate_G:6.25e-06
# epochs: 61 800/10176  degradation modeling stage: loss_D:0.246579 , loss_G: 1.795160 loss_G_cycle:0.143588 loss_feedback:0.006828
# epochs: 61 800/10176  deblurring stage :loss_deblur:0.068290
# epochs: 61 1600/10176  degradation modeling stage: loss_D:0.126553 , loss_G: 1.108206 loss_G_cycle:0.082384 loss_feedback:0.003961
# epochs: 61 1600/10176  deblurring stage :loss_deblur:0.039622
# epochs: 61 2400/10176  degradation modeling stage: loss_D:0.168142 , loss_G: 0.949402 loss_G_cycle:0.084029 loss_feedback:0.004004
# epochs: 61 2400/10176  deblurring stage :loss_deblur:0.040065
# epochs: 61 3200/10176  degradation modeling stage: loss_D:0.141417 , loss_G: 1.042295 loss_G_cycle:0.082927 loss_feedback:0.003931
# epochs: 61 3200/10176  deblurring stage :loss_deblur:0.039318
# epochs: 61 4000/10176  degradation modeling stage: loss_D:0.140844 , loss_G: 1.052373 loss_G_cycle:0.083230 loss_feedback:0.003998
# epochs: 61 4000/10176  deblurring stage :loss_deblur:0.040022
# epochs: 61 4800/10176  degradation modeling stage: loss_D:0.149384 , loss_G: 1.024577 loss_G_cycle:0.083444 loss_feedback:0.003994
# epochs: 61 4800/10176  deblurring stage :loss_deblur:0.039950
# epochs: 61 5600/10176  degradation modeling stage: loss_D:0.134585 , loss_G: 1.076816 loss_G_cycle:0.082805 loss_feedback:0.003964
# epochs: 61 5600/10176  deblurring stage :loss_deblur:0.039651
# epochs: 61 6400/10176  degradation modeling stage: loss_D:0.150146 , loss_G: 1.015516 loss_G_cycle:0.083392 loss_feedback:0.003983
# epochs: 61 6400/10176  deblurring stage :loss_deblur:0.039874
# epochs: 61 7200/10176  degradation modeling stage: loss_D:0.153686 , loss_G: 1.002095 loss_G_cycle:0.083790 loss_feedback:0.003973
# epochs: 61 7200/10176  deblurring stage :loss_deblur:0.039730
# epochs: 61 8000/10176  degradation modeling stage: loss_D:0.135969 , loss_G: 1.086382 loss_G_cycle:0.082998 loss_feedback:0.003969
# epochs: 61 8000/10176  deblurring stage :loss_deblur:0.039709
# epochs: 61 8800/10176  degradation modeling stage: loss_D:0.140065 , loss_G: 1.049985 loss_G_cycle:0.083616 loss_feedback:0.003997
# epochs: 61 8800/10176  deblurring stage :loss_deblur:0.040006
# epochs: 61 9600/10176  degradation modeling stage: loss_D:0.156046 , loss_G: 1.007661 loss_G_cycle:0.084114 loss_feedback:0.004007
# epochs: 61 9600/10176  deblurring stage :loss_deblur:0.040080
# epoch:62,learning_rate_D:6.25e-06
# epoch:62,learning_rate_G:6.25e-06
# epochs: 62 800/10176  degradation modeling stage: loss_D:0.237112 , loss_G: 1.850662 loss_G_cycle:0.143182 loss_feedback:0.006852
# epochs: 62 800/10176  deblurring stage :loss_deblur:0.068570
# epochs: 62 1600/10176  degradation modeling stage: loss_D:0.161149 , loss_G: 0.980445 loss_G_cycle:0.084014 loss_feedback:0.003965
# epochs: 62 1600/10176  deblurring stage :loss_deblur:0.039658
# epochs: 62 2400/10176  degradation modeling stage: loss_D:0.137119 , loss_G: 1.076966 loss_G_cycle:0.083500 loss_feedback:0.003955
# epochs: 62 2400/10176  deblurring stage :loss_deblur:0.039568
# epochs: 62 3200/10176  degradation modeling stage: loss_D:0.135176 , loss_G: 1.066319 loss_G_cycle:0.082735 loss_feedback:0.003961
# epochs: 62 3200/10176  deblurring stage :loss_deblur:0.039643
# epochs: 62 4000/10176  degradation modeling stage: loss_D:0.163049 , loss_G: 0.979938 loss_G_cycle:0.083721 loss_feedback:0.003999
# epochs: 62 4000/10176  deblurring stage :loss_deblur:0.040008
# epochs: 62 4800/10176  degradation modeling stage: loss_D:0.134811 , loss_G: 1.073260 loss_G_cycle:0.082928 loss_feedback:0.003965
# epochs: 62 4800/10176  deblurring stage :loss_deblur:0.039662
# epochs: 62 5600/10176  degradation modeling stage: loss_D:0.130996 , loss_G: 1.116605 loss_G_cycle:0.082939 loss_feedback:0.003981
# epochs: 62 5600/10176  deblurring stage :loss_deblur:0.039824
# epochs: 62 6400/10176  degradation modeling stage: loss_D:0.160044 , loss_G: 0.977261 loss_G_cycle:0.083567 loss_feedback:0.003984
# epochs: 62 6400/10176  deblurring stage :loss_deblur:0.039873
# epochs: 62 7200/10176  degradation modeling stage: loss_D:0.139077 , loss_G: 1.061030 loss_G_cycle:0.083509 loss_feedback:0.003961
# epochs: 62 7200/10176  deblurring stage :loss_deblur:0.039624
# epochs: 62 8000/10176  degradation modeling stage: loss_D:0.133112 , loss_G: 1.085603 loss_G_cycle:0.083193 loss_feedback:0.003958
# epochs: 62 8000/10176  deblurring stage :loss_deblur:0.039592
# epochs: 62 8800/10176  degradation modeling stage: loss_D:0.127699 , loss_G: 1.122190 loss_G_cycle:0.083387 loss_feedback:0.003984
# epochs: 62 8800/10176  deblurring stage :loss_deblur:0.039865
# epochs: 62 9600/10176  degradation modeling stage: loss_D:0.167188 , loss_G: 0.959201 loss_G_cycle:0.083786 loss_feedback:0.004013
# epochs: 62 9600/10176  deblurring stage :loss_deblur:0.040163
# epoch:63,learning_rate_D:6.25e-06
# epoch:63,learning_rate_G:6.25e-06
# epochs: 63 800/10176  degradation modeling stage: loss_D:0.239125 , loss_G: 1.818315 loss_G_cycle:0.142546 loss_feedback:0.006817
# epochs: 63 800/10176  deblurring stage :loss_deblur:0.068175
# epochs: 63 1600/10176  degradation modeling stage: loss_D:0.150491 , loss_G: 1.007230 loss_G_cycle:0.083911 loss_feedback:0.004000
# epochs: 63 1600/10176  deblurring stage :loss_deblur:0.040031
# epochs: 63 2400/10176  degradation modeling stage: loss_D:0.150974 , loss_G: 1.029611 loss_G_cycle:0.083448 loss_feedback:0.003961
# epochs: 63 2400/10176  deblurring stage :loss_deblur:0.039620
# epochs: 63 3200/10176  degradation modeling stage: loss_D:0.130687 , loss_G: 1.099172 loss_G_cycle:0.083068 loss_feedback:0.003958
# epochs: 63 3200/10176  deblurring stage :loss_deblur:0.039597
# epochs: 63 4000/10176  degradation modeling stage: loss_D:0.159793 , loss_G: 0.990326 loss_G_cycle:0.083962 loss_feedback:0.004010
# epochs: 63 4000/10176  deblurring stage :loss_deblur:0.040137
# epochs: 63 4800/10176  degradation modeling stage: loss_D:0.142372 , loss_G: 1.046649 loss_G_cycle:0.083201 loss_feedback:0.003975
# epochs: 63 4800/10176  deblurring stage :loss_deblur:0.039756
# epochs: 63 5600/10176  degradation modeling stage: loss_D:0.133511 , loss_G: 1.082223 loss_G_cycle:0.082415 loss_feedback:0.003967
# epochs: 63 5600/10176  deblurring stage :loss_deblur:0.039692
# epochs: 63 6400/10176  degradation modeling stage: loss_D:0.161059 , loss_G: 0.986270 loss_G_cycle:0.083967 loss_feedback:0.004000
# epochs: 63 6400/10176  deblurring stage :loss_deblur:0.040019
# epochs: 63 7200/10176  degradation modeling stage: loss_D:0.141112 , loss_G: 1.052563 loss_G_cycle:0.082840 loss_feedback:0.003933
# epochs: 63 7200/10176  deblurring stage :loss_deblur:0.039339
# epochs: 63 8000/10176  degradation modeling stage: loss_D:0.131823 , loss_G: 1.099483 loss_G_cycle:0.083220 loss_feedback:0.003963
# epochs: 63 8000/10176  deblurring stage :loss_deblur:0.039658
# epochs: 63 8800/10176  degradation modeling stage: loss_D:0.134643 , loss_G: 1.102506 loss_G_cycle:0.083221 loss_feedback:0.003946
# epochs: 63 8800/10176  deblurring stage :loss_deblur:0.039472
# epochs: 63 9600/10176  degradation modeling stage: loss_D:0.142692 , loss_G: 1.049823 loss_G_cycle:0.083191 loss_feedback:0.003978
# epochs: 63 9600/10176  deblurring stage :loss_deblur:0.039825
# epoch:64,learning_rate_D:6.25e-06
# epoch:64,learning_rate_G:6.25e-06
# epochs: 64 800/10176  degradation modeling stage: loss_D:0.250792 , loss_G: 1.797845 loss_G_cycle:0.144320 loss_feedback:0.006842
# epochs: 64 800/10176  deblurring stage :loss_deblur:0.068438
# epochs: 64 1600/10176  degradation modeling stage: loss_D:0.156785 , loss_G: 0.983913 loss_G_cycle:0.083819 loss_feedback:0.003981
# epochs: 64 1600/10176  deblurring stage :loss_deblur:0.039837
# epochs: 64 2400/10176  degradation modeling stage: loss_D:0.143116 , loss_G: 1.048631 loss_G_cycle:0.083120 loss_feedback:0.003943
# epochs: 64 2400/10176  deblurring stage :loss_deblur:0.039447
# epochs: 64 3200/10176  degradation modeling stage: loss_D:0.129711 , loss_G: 1.112486 loss_G_cycle:0.082838 loss_feedback:0.003946
# epochs: 64 3200/10176  deblurring stage :loss_deblur:0.039466
# epochs: 64 4000/10176  degradation modeling stage: loss_D:0.133402 , loss_G: 1.080382 loss_G_cycle:0.083123 loss_feedback:0.003946
# epochs: 64 4000/10176  deblurring stage :loss_deblur:0.039512
# epochs: 64 4800/10176  degradation modeling stage: loss_D:0.163915 , loss_G: 0.973590 loss_G_cycle:0.083819 loss_feedback:0.004004
# epochs: 64 4800/10176  deblurring stage :loss_deblur:0.040047
# epochs: 64 5600/10176  degradation modeling stage: loss_D:0.132577 , loss_G: 1.096620 loss_G_cycle:0.082840 loss_feedback:0.003983
# epochs: 64 5600/10176  deblurring stage :loss_deblur:0.039845
# epochs: 64 6400/10176  degradation modeling stage: loss_D:0.143849 , loss_G: 1.054923 loss_G_cycle:0.083283 loss_feedback:0.003999
# epochs: 64 6400/10176  deblurring stage :loss_deblur:0.040032
# epochs: 64 7200/10176  degradation modeling stage: loss_D:0.154764 , loss_G: 0.991966 loss_G_cycle:0.083523 loss_feedback:0.003989
# epochs: 64 7200/10176  deblurring stage :loss_deblur:0.039899
# epochs: 64 8000/10176  degradation modeling stage: loss_D:0.134542 , loss_G: 1.094080 loss_G_cycle:0.082957 loss_feedback:0.003934
# epochs: 64 8000/10176  deblurring stage :loss_deblur:0.039354
# epochs: 64 8800/10176  degradation modeling stage: loss_D:0.144299 , loss_G: 1.044784 loss_G_cycle:0.083370 loss_feedback:0.003975
# epochs: 64 8800/10176  deblurring stage :loss_deblur:0.039794
# epochs: 64 9600/10176  degradation modeling stage: loss_D:0.154238 , loss_G: 1.025914 loss_G_cycle:0.084145 loss_feedback:0.004014
# epochs: 64 9600/10176  deblurring stage :loss_deblur:0.040153
# epoch:65,learning_rate_D:6.25e-06
# epoch:65,learning_rate_G:6.25e-06
# epochs: 65 800/10176  degradation modeling stage: loss_D:0.222618 , loss_G: 1.879229 loss_G_cycle:0.142803 loss_feedback:0.006822
# epochs: 65 800/10176  deblurring stage :loss_deblur:0.068247
# epochs: 65 1600/10176  degradation modeling stage: loss_D:0.165333 , loss_G: 0.966129 loss_G_cycle:0.083820 loss_feedback:0.003987
# epochs: 65 1600/10176  deblurring stage :loss_deblur:0.039899
# epochs: 65 2400/10176  degradation modeling stage: loss_D:0.137185 , loss_G: 1.060555 loss_G_cycle:0.082670 loss_feedback:0.003961
# epochs: 65 2400/10176  deblurring stage :loss_deblur:0.039628
# epochs: 65 3200/10176  degradation modeling stage: loss_D:0.129465 , loss_G: 1.114915 loss_G_cycle:0.083028 loss_feedback:0.003944
# epochs: 65 3200/10176  deblurring stage :loss_deblur:0.039454
# epochs: 65 4000/10176  degradation modeling stage: loss_D:0.125084 , loss_G: 1.120397 loss_G_cycle:0.082558 loss_feedback:0.003945
# epochs: 65 4000/10176  deblurring stage :loss_deblur:0.039464
# epochs: 65 4800/10176  degradation modeling stage: loss_D:0.123248 , loss_G: 1.132848 loss_G_cycle:0.082864 loss_feedback:0.003962
# epochs: 65 4800/10176  deblurring stage :loss_deblur:0.039641
# epochs: 65 5600/10176  degradation modeling stage: loss_D:0.124092 , loss_G: 1.145757 loss_G_cycle:0.082861 loss_feedback:0.003959
# epochs: 65 5600/10176  deblurring stage :loss_deblur:0.039611
# epochs: 65 6400/10176  degradation modeling stage: loss_D:0.160693 , loss_G: 1.000808 loss_G_cycle:0.083680 loss_feedback:0.003987
# epochs: 65 6400/10176  deblurring stage :loss_deblur:0.039906
# epochs: 65 7200/10176  degradation modeling stage: loss_D:0.149779 , loss_G: 1.035909 loss_G_cycle:0.083580 loss_feedback:0.003980
# epochs: 65 7200/10176  deblurring stage :loss_deblur:0.039809
# epochs: 65 8000/10176  degradation modeling stage: loss_D:0.132570 , loss_G: 1.087248 loss_G_cycle:0.082740 loss_feedback:0.003977
# epochs: 65 8000/10176  deblurring stage :loss_deblur:0.039784
# epochs: 65 8800/10176  degradation modeling stage: loss_D:0.162388 , loss_G: 0.978746 loss_G_cycle:0.083625 loss_feedback:0.003986
# epochs: 65 8800/10176  deblurring stage :loss_deblur:0.039882
# epochs: 65 9600/10176  degradation modeling stage: loss_D:0.135487 , loss_G: 1.073471 loss_G_cycle:0.082951 loss_feedback:0.003968
# epochs: 65 9600/10176  deblurring stage :loss_deblur:0.039690
# epoch:66,learning_rate_D:6.25e-06
# epoch:66,learning_rate_G:6.25e-06
# epochs: 66 800/10176  degradation modeling stage: loss_D:0.259113 , loss_G: 1.753023 loss_G_cycle:0.143759 loss_feedback:0.006856
# epochs: 66 800/10176  deblurring stage :loss_deblur:0.068606
# epochs: 66 1600/10176  degradation modeling stage: loss_D:0.132521 , loss_G: 1.080298 loss_G_cycle:0.083071 loss_feedback:0.003964
# epochs: 66 1600/10176  deblurring stage :loss_deblur:0.039646
# epochs: 66 2400/10176  degradation modeling stage: loss_D:0.155161 , loss_G: 0.988947 loss_G_cycle:0.084366 loss_feedback:0.004011
# epochs: 66 2400/10176  deblurring stage :loss_deblur:0.040145
# epochs: 66 3200/10176  degradation modeling stage: loss_D:0.147476 , loss_G: 1.024310 loss_G_cycle:0.082969 loss_feedback:0.003946
# epochs: 66 3200/10176  deblurring stage :loss_deblur:0.039476
# epochs: 66 4000/10176  degradation modeling stage: loss_D:0.130233 , loss_G: 1.108891 loss_G_cycle:0.083796 loss_feedback:0.003965
# epochs: 66 4000/10176  deblurring stage :loss_deblur:0.039661
# epochs: 66 4800/10176  degradation modeling stage: loss_D:0.129405 , loss_G: 1.133548 loss_G_cycle:0.083128 loss_feedback:0.003955
# epochs: 66 4800/10176  deblurring stage :loss_deblur:0.039571
# epochs: 66 5600/10176  degradation modeling stage: loss_D:0.132097 , loss_G: 1.098230 loss_G_cycle:0.083097 loss_feedback:0.003938
# epochs: 66 5600/10176  deblurring stage :loss_deblur:0.039435
# epochs: 66 6400/10176  degradation modeling stage: loss_D:0.163604 , loss_G: 0.992793 loss_G_cycle:0.083764 loss_feedback:0.003974
# epochs: 66 6400/10176  deblurring stage :loss_deblur:0.039751
# epochs: 66 7200/10176  degradation modeling stage: loss_D:0.138659 , loss_G: 1.081939 loss_G_cycle:0.082981 loss_feedback:0.003969
# epochs: 66 7200/10176  deblurring stage :loss_deblur:0.039698
# epochs: 66 8000/10176  degradation modeling stage: loss_D:0.130095 , loss_G: 1.085347 loss_G_cycle:0.083594 loss_feedback:0.003973
# epochs: 66 8000/10176  deblurring stage :loss_deblur:0.039755
# epochs: 66 8800/10176  degradation modeling stage: loss_D:0.162976 , loss_G: 0.965278 loss_G_cycle:0.084021 loss_feedback:0.003989
# epochs: 66 8800/10176  deblurring stage :loss_deblur:0.039914
# epochs: 66 9600/10176  degradation modeling stage: loss_D:0.136030 , loss_G: 1.084673 loss_G_cycle:0.083121 loss_feedback:0.003954
# epochs: 66 9600/10176  deblurring stage :loss_deblur:0.039552
# epoch:67,learning_rate_D:6.25e-06
# epoch:67,learning_rate_G:6.25e-06
# epochs: 67 800/10176  degradation modeling stage: loss_D:0.221674 , loss_G: 1.921864 loss_G_cycle:0.143173 loss_feedback:0.006791
# epochs: 67 800/10176  deblurring stage :loss_deblur:0.067955
# epochs: 67 1600/10176  degradation modeling stage: loss_D:0.167189 , loss_G: 0.985169 loss_G_cycle:0.083980 loss_feedback:0.003977
# epochs: 67 1600/10176  deblurring stage :loss_deblur:0.039784
# epochs: 67 2400/10176  degradation modeling stage: loss_D:0.135845 , loss_G: 1.083390 loss_G_cycle:0.083376 loss_feedback:0.003960
# epochs: 67 2400/10176  deblurring stage :loss_deblur:0.039609
# epochs: 67 3200/10176  degradation modeling stage: loss_D:0.142584 , loss_G: 1.056265 loss_G_cycle:0.083113 loss_feedback:0.003963
# epochs: 67 3200/10176  deblurring stage :loss_deblur:0.039661
# epochs: 67 4000/10176  degradation modeling stage: loss_D:0.157961 , loss_G: 1.002306 loss_G_cycle:0.083523 loss_feedback:0.003993
# epochs: 67 4000/10176  deblurring stage :loss_deblur:0.039926
# epochs: 67 4800/10176  degradation modeling stage: loss_D:0.132288 , loss_G: 1.103764 loss_G_cycle:0.083040 loss_feedback:0.003961
# epochs: 67 4800/10176  deblurring stage :loss_deblur:0.039619
# epochs: 67 5600/10176  degradation modeling stage: loss_D:0.144054 , loss_G: 1.042183 loss_G_cycle:0.082936 loss_feedback:0.003964
# epochs: 67 5600/10176  deblurring stage :loss_deblur:0.039677
# ...
# epochs: 144 4000/10176  deblurring stage :loss_deblur:0.039376
# epochs: 144 4800/10176  degradation modeling stage: loss_D:0.115552 , loss_G: 1.222409 loss_G_cycle:0.082634 loss_feedback:0.003931
# epochs: 144 4800/10176  deblurring stage :loss_deblur:0.039305
# epochs: 144 5600/10176  degradation modeling stage: loss_D:0.111765 , loss_G: 1.234786 loss_G_cycle:0.082706 loss_feedback:0.003958
# epochs: 144 5600/10176  deblurring stage :loss_deblur:0.039580
# epochs: 144 6400/10176  degradation modeling stage: loss_D:0.113102 , loss_G: 1.228622 loss_G_cycle:0.082502 loss_feedback:0.003940
# epochs: 144 6400/10176  deblurring stage :loss_deblur:0.039396
# epochs: 144 7200/10176  degradation modeling stage: loss_D:0.114881 , loss_G: 1.223935 loss_G_cycle:0.082828 loss_feedback:0.003917
# epochs: 144 7200/10176  deblurring stage :loss_deblur:0.039169
# epochs: 144 8000/10176  degradation modeling stage: loss_D:0.116673 , loss_G: 1.221696 loss_G_cycle:0.082088 loss_feedback:0.003939
# epochs: 144 8000/10176  deblurring stage :loss_deblur:0.039390
# epochs: 144 8800/10176  degradation modeling stage: loss_D:0.116172 , loss_G: 1.212383 loss_G_cycle:0.082242 loss_feedback:0.003925
# epochs: 144 8800/10176  deblurring stage :loss_deblur:0.039249
# epochs: 144 9600/10176  degradation modeling stage: loss_D:0.117271 , loss_G: 1.217814 loss_G_cycle:0.082939 loss_feedback:0.003952
# epochs: 144 9600/10176  deblurring stage :loss_deblur:0.039521
# epoch:145,learning_rate_D:1.953125e-07
# epoch:145,learning_rate_G:1.953125e-07
# epochs: 145 800/10176  degradation modeling stage: loss_D:0.194103 , loss_G: 2.105067 loss_G_cycle:0.142070 loss_feedback:0.006795
# epochs: 145 800/10176  deblurring stage :loss_deblur:0.067955
# epochs: 145 1600/10176  degradation modeling stage: loss_D:0.118185 , loss_G: 1.219709 loss_G_cycle:0.081940 loss_feedback:0.003917
# epochs: 145 1600/10176  deblurring stage :loss_deblur:0.039170
# epochs: 145 2400/10176  degradation modeling stage: loss_D:0.115188 , loss_G: 1.227308 loss_G_cycle:0.082666 loss_feedback:0.003933
# epochs: 145 2400/10176  deblurring stage :loss_deblur:0.039334
# epochs: 145 3200/10176  degradation modeling stage: loss_D:0.114079 , loss_G: 1.222321 loss_G_cycle:0.082532 loss_feedback:0.003946
# epochs: 145 3200/10176  deblurring stage :loss_deblur:0.039456
# epochs: 145 4000/10176  degradation modeling stage: loss_D:0.114601 , loss_G: 1.229169 loss_G_cycle:0.082736 loss_feedback:0.003946
# epochs: 145 4000/10176  deblurring stage :loss_deblur:0.039463
# epochs: 145 4800/10176  degradation modeling stage: loss_D:0.112975 , loss_G: 1.230741 loss_G_cycle:0.082424 loss_feedback:0.003947
# epochs: 145 4800/10176  deblurring stage :loss_deblur:0.039470
# epochs: 145 5600/10176  degradation modeling stage: loss_D:0.117968 , loss_G: 1.218074 loss_G_cycle:0.082399 loss_feedback:0.003929
# epochs: 145 5600/10176  deblurring stage :loss_deblur:0.039285
# epochs: 145 6400/10176  degradation modeling stage: loss_D:0.114990 , loss_G: 1.224802 loss_G_cycle:0.082510 loss_feedback:0.003948
# epochs: 145 6400/10176  deblurring stage :loss_deblur:0.039484
# epochs: 145 7200/10176  degradation modeling stage: loss_D:0.117529 , loss_G: 1.220059 loss_G_cycle:0.082719 loss_feedback:0.003925
# epochs: 145 7200/10176  deblurring stage :loss_deblur:0.039247
# epochs: 145 8000/10176  degradation modeling stage: loss_D:0.108877 , loss_G: 1.227341 loss_G_cycle:0.082584 loss_feedback:0.003954
# epochs: 145 8000/10176  deblurring stage :loss_deblur:0.039544
# epochs: 145 8800/10176  degradation modeling stage: loss_D:0.115935 , loss_G: 1.234541 loss_G_cycle:0.082470 loss_feedback:0.003916
# epochs: 145 8800/10176  deblurring stage :loss_deblur:0.039158
# epochs: 145 9600/10176  degradation modeling stage: loss_D:0.112949 , loss_G: 1.233565 loss_G_cycle:0.082406 loss_feedback:0.003940
# epochs: 145 9600/10176  deblurring stage :loss_deblur:0.039402
# epoch:146,learning_rate_D:1.953125e-07
# epoch:146,learning_rate_G:1.953125e-07
# epochs: 146 800/10176  degradation modeling stage: loss_D:0.194492 , loss_G: 2.101021 loss_G_cycle:0.141577 loss_feedback:0.006749
# epochs: 146 800/10176  deblurring stage :loss_deblur:0.067492
# epochs: 146 1600/10176  degradation modeling stage: loss_D:0.112935 , loss_G: 1.236598 loss_G_cycle:0.082597 loss_feedback:0.003931
# epochs: 146 1600/10176  deblurring stage :loss_deblur:0.039308
# epochs: 146 2400/10176  degradation modeling stage: loss_D:0.121608 , loss_G: 1.215937 loss_G_cycle:0.082568 loss_feedback:0.003940
# epochs: 146 2400/10176  deblurring stage :loss_deblur:0.039400
# epochs: 146 3200/10176  degradation modeling stage: loss_D:0.116035 , loss_G: 1.217279 loss_G_cycle:0.082424 loss_feedback:0.003937
# epochs: 146 3200/10176  deblurring stage :loss_deblur:0.039373
# epochs: 146 4000/10176  degradation modeling stage: loss_D:0.119961 , loss_G: 1.210995 loss_G_cycle:0.082638 loss_feedback:0.003954
# epochs: 146 4000/10176  deblurring stage :loss_deblur:0.039539
# epochs: 146 4800/10176  degradation modeling stage: loss_D:0.111791 , loss_G: 1.214426 loss_G_cycle:0.082745 loss_feedback:0.003948
# epochs: 146 4800/10176  deblurring stage :loss_deblur:0.039484
# epochs: 146 5600/10176  degradation modeling stage: loss_D:0.112209 , loss_G: 1.239373 loss_G_cycle:0.082710 loss_feedback:0.003954
# epochs: 146 5600/10176  deblurring stage :loss_deblur:0.039540
# epochs: 146 6400/10176  degradation modeling stage: loss_D:0.117337 , loss_G: 1.212286 loss_G_cycle:0.082562 loss_feedback:0.003923
# epochs: 146 6400/10176  deblurring stage :loss_deblur:0.039226
# epochs: 146 7200/10176  degradation modeling stage: loss_D:0.116751 , loss_G: 1.218155 loss_G_cycle:0.082396 loss_feedback:0.003921
# epochs: 146 7200/10176  deblurring stage :loss_deblur:0.039215
# epochs: 146 8000/10176  degradation modeling stage: loss_D:0.116578 , loss_G: 1.220072 loss_G_cycle:0.082820 loss_feedback:0.003946
# epochs: 146 8000/10176  deblurring stage :loss_deblur:0.039456
# epochs: 146 8800/10176  degradation modeling stage: loss_D:0.121527 , loss_G: 1.223193 loss_G_cycle:0.082418 loss_feedback:0.003945
# epochs: 146 8800/10176  deblurring stage :loss_deblur:0.039450
# epochs: 146 9600/10176  degradation modeling stage: loss_D:0.126597 , loss_G: 1.136180 loss_G_cycle:0.083058 loss_feedback:0.003996
# epochs: 146 9600/10176  deblurring stage :loss_deblur:0.039974
# epoch:147,learning_rate_D:1.953125e-07
# epoch:147,learning_rate_G:1.953125e-07
# epochs: 147 800/10176  degradation modeling stage: loss_D:0.360535 , loss_G: 1.544762 loss_G_cycle:0.143921 loss_feedback:0.006870
# epochs: 147 800/10176  deblurring stage :loss_deblur:0.068708
# epochs: 147 1600/10176  degradation modeling stage: loss_D:0.219721 , loss_G: 0.900062 loss_G_cycle:0.083633 loss_feedback:0.004007
# epochs: 147 1600/10176  deblurring stage :loss_deblur:0.040069
# epochs: 147 2400/10176  degradation modeling stage: loss_D:0.213761 , loss_G: 0.905695 loss_G_cycle:0.083319 loss_feedback:0.004008
# epochs: 147 2400/10176  deblurring stage :loss_deblur:0.040084
# epochs: 147 3200/10176  degradation modeling stage: loss_D:0.212206 , loss_G: 0.906619 loss_G_cycle:0.083766 loss_feedback:0.004012
# epochs: 147 3200/10176  deblurring stage :loss_deblur:0.040124
# epochs: 147 4000/10176  degradation modeling stage: loss_D:0.209193 , loss_G: 0.930575 loss_G_cycle:0.083913 loss_feedback:0.004008
# epochs: 147 4000/10176  deblurring stage :loss_deblur:0.040078
# epochs: 147 4800/10176  degradation modeling stage: loss_D:0.198244 , loss_G: 0.938023 loss_G_cycle:0.083561 loss_feedback:0.004003
# epochs: 147 4800/10176  deblurring stage :loss_deblur:0.040029
# epochs: 147 5600/10176  degradation modeling stage: loss_D:0.197138 , loss_G: 0.966960 loss_G_cycle:0.083613 loss_feedback:0.004002
# epochs: 147 5600/10176  deblurring stage :loss_deblur:0.040019
# epochs: 147 6400/10176  degradation modeling stage: loss_D:0.189958 , loss_G: 0.959146 loss_G_cycle:0.083564 loss_feedback:0.003986
# epochs: 147 6400/10176  deblurring stage :loss_deblur:0.039860
# epochs: 147 7200/10176  degradation modeling stage: loss_D:0.184316 , loss_G: 0.977125 loss_G_cycle:0.083746 loss_feedback:0.003987
# epochs: 147 7200/10176  deblurring stage :loss_deblur:0.039866
# epochs: 147 8000/10176  degradation modeling stage: loss_D:0.181010 , loss_G: 0.980685 loss_G_cycle:0.083753 loss_feedback:0.004002
# epochs: 147 8000/10176  deblurring stage :loss_deblur:0.040017
# epochs: 147 8800/10176  degradation modeling stage: loss_D:0.177828 , loss_G: 0.992678 loss_G_cycle:0.083623 loss_feedback:0.003987
# epochs: 147 8800/10176  deblurring stage :loss_deblur:0.039874
# epochs: 147 9600/10176  degradation modeling stage: loss_D:0.174412 , loss_G: 1.003160 loss_G_cycle:0.083355 loss_feedback:0.003966
# epochs: 147 9600/10176  deblurring stage :loss_deblur:0.039658
# epoch:148,learning_rate_D:1.953125e-07
# epoch:148,learning_rate_G:1.953125e-07
# epochs: 148 800/10176  degradation modeling stage: loss_D:0.293052 , loss_G: 1.735033 loss_G_cycle:0.143969 loss_feedback:0.006818
# epochs: 148 800/10176  deblurring stage :loss_deblur:0.068179
# epochs: 148 1600/10176  degradation modeling stage: loss_D:0.164570 , loss_G: 1.019700 loss_G_cycle:0.083301 loss_feedback:0.003974
# epochs: 148 1600/10176  deblurring stage :loss_deblur:0.039740
# epochs: 148 2400/10176  degradation modeling stage: loss_D:0.163615 , loss_G: 1.048987 loss_G_cycle:0.083580 loss_feedback:0.003991
# epochs: 148 2400/10176  deblurring stage :loss_deblur:0.039910
# epochs: 148 3200/10176  degradation modeling stage: loss_D:0.158474 , loss_G: 1.035220 loss_G_cycle:0.083453 loss_feedback:0.003971
# epochs: 148 3200/10176  deblurring stage :loss_deblur:0.039706
# epochs: 148 4000/10176  degradation modeling stage: loss_D:0.157784 , loss_G: 1.037277 loss_G_cycle:0.083479 loss_feedback:0.003976
# epochs: 148 4000/10176  deblurring stage :loss_deblur:0.039763
# epochs: 148 4800/10176  degradation modeling stage: loss_D:0.155907 , loss_G: 1.053862 loss_G_cycle:0.083376 loss_feedback:0.003949
# epochs: 148 4800/10176  deblurring stage :loss_deblur:0.039492
# epochs: 148 5600/10176  degradation modeling stage: loss_D:0.151213 , loss_G: 1.061781 loss_G_cycle:0.083158 loss_feedback:0.003976
# epochs: 148 5600/10176  deblurring stage :loss_deblur:0.039755
# epochs: 148 6400/10176  degradation modeling stage: loss_D:0.149255 , loss_G: 1.080877 loss_G_cycle:0.083649 loss_feedback:0.003979
# epochs: 148 6400/10176  deblurring stage :loss_deblur:0.039791
# epochs: 148 7200/10176  degradation modeling stage: loss_D:0.150138 , loss_G: 1.077289 loss_G_cycle:0.083331 loss_feedback:0.003966
# epochs: 148 7200/10176  deblurring stage :loss_deblur:0.039659
# epochs: 148 8000/10176  degradation modeling stage: loss_D:0.147119 , loss_G: 1.060946 loss_G_cycle:0.083174 loss_feedback:0.003957
# epochs: 148 8000/10176  deblurring stage :loss_deblur:0.039568
# epochs: 148 8800/10176  degradation modeling stage: loss_D:0.144486 , loss_G: 1.084073 loss_G_cycle:0.083381 loss_feedback:0.003956
# epochs: 148 8800/10176  deblurring stage :loss_deblur:0.039559
# epochs: 148 9600/10176  degradation modeling stage: loss_D:0.145702 , loss_G: 1.084671 loss_G_cycle:0.082932 loss_feedback:0.003951
# epochs: 148 9600/10176  deblurring stage :loss_deblur:0.039506
# epoch:149,learning_rate_D:1.953125e-07
# epoch:149,learning_rate_G:1.953125e-07
# epochs: 149 800/10176  degradation modeling stage: loss_D:0.246431 , loss_G: 1.881069 loss_G_cycle:0.143033 loss_feedback:0.006803
# epochs: 149 800/10176  deblurring stage :loss_deblur:0.068031
# epochs: 149 1600/10176  degradation modeling stage: loss_D:0.140085 , loss_G: 1.103005 loss_G_cycle:0.082700 loss_feedback:0.003943
# epochs: 149 1600/10176  deblurring stage :loss_deblur:0.039428
# epochs: 149 2400/10176  degradation modeling stage: loss_D:0.139217 , loss_G: 1.104692 loss_G_cycle:0.083359 loss_feedback:0.003968
# epochs: 149 2400/10176  deblurring stage :loss_deblur:0.039680
# epochs: 149 3200/10176  degradation modeling stage: loss_D:0.139230 , loss_G: 1.101019 loss_G_cycle:0.082525 loss_feedback:0.003956
# epochs: 149 3200/10176  deblurring stage :loss_deblur:0.039565
# epochs: 149 4000/10176  degradation modeling stage: loss_D:0.137357 , loss_G: 1.097413 loss_G_cycle:0.082700 loss_feedback:0.003934
# epochs: 149 4000/10176  deblurring stage :loss_deblur:0.039338
# epochs: 149 4800/10176  degradation modeling stage: loss_D:0.133146 , loss_G: 1.126309 loss_G_cycle:0.083168 loss_feedback:0.003961
# epochs: 149 4800/10176  deblurring stage :loss_deblur:0.039611
# epochs: 149 5600/10176  degradation modeling stage: loss_D:0.132516 , loss_G: 1.120244 loss_G_cycle:0.083153 loss_feedback:0.003952
# epochs: 149 5600/10176  deblurring stage :loss_deblur:0.039517
# epochs: 149 6400/10176  degradation modeling stage: loss_D:0.132784 , loss_G: 1.123582 loss_G_cycle:0.082718 loss_feedback:0.003936
# epochs: 149 6400/10176  deblurring stage :loss_deblur:0.039364
# epochs: 149 7200/10176  degradation modeling stage: loss_D:0.132810 , loss_G: 1.127999 loss_G_cycle:0.082843 loss_feedback:0.003957
# epochs: 149 7200/10176  deblurring stage :loss_deblur:0.039573
# epochs: 149 8000/10176  degradation modeling stage: loss_D:0.133922 , loss_G: 1.123002 loss_G_cycle:0.082696 loss_feedback:0.003952
# epochs: 149 8000/10176  deblurring stage :loss_deblur:0.039517
# epochs: 149 8800/10176  degradation modeling stage: loss_D:0.129245 , loss_G: 1.127926 loss_G_cycle:0.083107 loss_feedback:0.003968
# epochs: 149 8800/10176  deblurring stage :loss_deblur:0.039682
# epochs: 149 9600/10176  degradation modeling stage: loss_D:0.129927 , loss_G: 1.129676 loss_G_cycle:0.082363 loss_feedback:0.003955
# epochs: 149 9600/10176  deblurring stage :loss_deblur:0.039548
# epoch:150,learning_rate_D:9.765625e-08
# epoch:150,learning_rate_G:9.765625e-08
# epochs: 150 800/10176  degradation modeling stage: loss_D:0.223731 , loss_G: 1.960739 loss_G_cycle:0.142010 loss_feedback:0.006770
# epochs: 150 800/10176  deblurring stage :loss_deblur:0.067699
# epochs: 150 1600/10176  degradation modeling stage: loss_D:0.128532 , loss_G: 1.141617 loss_G_cycle:0.082597 loss_feedback:0.003934
# epochs: 150 1600/10176  deblurring stage :loss_deblur:0.039340
# epochs: 150 2400/10176  degradation modeling stage: loss_D:0.123897 , loss_G: 1.144936 loss_G_cycle:0.082690 loss_feedback:0.003946
# epochs: 150 2400/10176  deblurring stage :loss_deblur:0.039458
# epochs: 150 3200/10176  degradation modeling stage: loss_D:0.127481 , loss_G: 1.143585 loss_G_cycle:0.082463 loss_feedback:0.003940
# epochs: 150 3200/10176  deblurring stage :loss_deblur:0.039399
# epochs: 150 4000/10176  degradation modeling stage: loss_D:0.124074 , loss_G: 1.152135 loss_G_cycle:0.082475 loss_feedback:0.003948
# epochs: 150 4000/10176  deblurring stage :loss_deblur:0.039484
# epochs: 150 4800/10176  degradation modeling stage: loss_D:0.126213 , loss_G: 1.155299 loss_G_cycle:0.082589 loss_feedback:0.003933
# epochs: 150 4800/10176  deblurring stage :loss_deblur:0.039334
# epochs: 150 5600/10176  degradation modeling stage: loss_D:0.127533 , loss_G: 1.148238 loss_G_cycle:0.082607 loss_feedback:0.003947
# epochs: 150 5600/10176  deblurring stage :loss_deblur:0.039470
# epochs: 150 6400/10176  degradation modeling stage: loss_D:0.127494 , loss_G: 1.159520 loss_G_cycle:0.082695 loss_feedback:0.003966
# epochs: 150 6400/10176  deblurring stage :loss_deblur:0.039661
# epochs: 150 7200/10176  degradation modeling stage: loss_D:0.124942 , loss_G: 1.156399 loss_G_cycle:0.082705 loss_feedback:0.003950
# epochs: 150 7200/10176  deblurring stage :loss_deblur:0.039502
# epochs: 150 8000/10176  degradation modeling stage: loss_D:0.124962 , loss_G: 1.149294 loss_G_cycle:0.082043 loss_feedback:0.003919
# epochs: 150 8000/10176  deblurring stage :loss_deblur:0.039191
# epochs: 150 8800/10176  degradation modeling stage: loss_D:0.126057 , loss_G: 1.151810 loss_G_cycle:0.082437 loss_feedback:0.003941
# epochs: 150 8800/10176  deblurring stage :loss_deblur:0.039409
# epochs: 150 9600/10176  degradation modeling stage: loss_D:0.122362 , loss_G: 1.152821 loss_G_cycle:0.082531 loss_feedback:0.003935
# epochs: 150 9600/10176  deblurring stage :loss_deblur:0.039346
# done training!
