# %%
import torch
print(torch.cuda.is_available()) 
from Supporting_functions import *

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'        
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# True

# %% [markdown]
# # Training SelfNet

# %%
# Define paths and paramters

# Models

path = r'\\WS2\WS2_Remote_Disk\Current Segovia Lab\Cristian_Selfnet\Selfnet\Selfnet_training\models\Fibrosis\FibrosisNuclei/'

batch_size = 10
epochs = 100

min_v = 0
max_v = 65535
pairedDataSets = False

learning_rate_G = 1e-4
learning_rate_D = 1e-4
beta1 = 0.5
beta2 = 0.999
log_interval = 500
imshow_interval = 500

input_nc = 1
output_nc = 1
        
# CUDA device
device=torch.device('cuda:0')

# Create varibale args
class TrainingArgs():
    pass

args = TrainingArgs()
args.path = path
args.batch_size = batch_size
args.epochs = epochs
args.min_v = min_v
args.max_v = max_v
args.learning_rate_G = learning_rate_G
args.learning_rate_D = learning_rate_D
args.beta1 = beta1
args.beta2 = beta2
args.log_interval = log_interval
args.imshow_interval = imshow_interval

# %%
# Create folder for output and cheking points

traning_data_path  = os.path.join(path,'train_data/train_data.npz')
checkpoint_path = os.path.join(path,'checkpoint/')

if not os.path.exists(checkpoint_path):
    os.mkdir(checkpoint_path)

model_saved_path = os.path.join(checkpoint_path,'saved_models/')
intermediate_results_path = os.path.join(checkpoint_path,'intermediate_results/')

if not os.path.exists(model_saved_path):
    os.mkdir(model_saved_path)

if not os.path.exists(intermediate_results_path):
    os.mkdir(intermediate_results_path)

# %%
# Prepare networks
netD_A = Self_net_architecture.define_D(input_nc=input_nc, ndf=64, netD='n_layers', n_layers_D=2, device=device,norm='instance')
netD_B = Self_net_architecture.define_D(input_nc=input_nc, ndf=64, netD='n_layers', n_layers_D=2, device=device,norm='instance')

netG_A = Self_net_architecture.define_G(input_nc=input_nc, output_nc=output_nc, ngf=64, netG='deblur_net', device=device,use_dropout=False,norm='instance')
netG_B = Self_net_architecture.define_G(input_nc=input_nc, output_nc=output_nc, ngf=64, netG='deblur_net', device=device,use_dropout=False,norm='instance')

deblur_net=Self_net_architecture.define_G(input_nc=input_nc, output_nc=output_nc, ngf=64, netG='deblur_net', device=device,use_dropout=False,norm='instance')

# Define loss functions
criterionGAN=Self_net_architecture.GANLoss(gan_mode='lsgan').to(device)
SSIM_loss = SSIM(data_range=1, size_average=True, win_size=11, win_sigma=1.5, channel=1)
criterionL1=L1_Charbonnier_loss()

# Optimizers
optimG = optim.Adam(itertools.chain(netG_A.parameters(), netG_B.parameters()),lr=learning_rate_G, betas=(beta1, beta2))
optimD=optim.Adam(itertools.chain(netD_A.parameters(),netD_B.parameters()),lr=learning_rate_D, betas=(beta1, beta2))
optim_deblur=optim.Adam(deblur_net.parameters(),lr=learning_rate_G, betas=(beta1, beta2))

# Training
train_set=pytorch_dataset.create_train_data(traning_data_path,batch_size,min_v,max_v, pairedDataSets)
train(train_set,netD_A,netD_B,netG_A,netG_B,deblur_net,args,device,criterionGAN,criterionL1,SSIM_loss,optimD,optimG,optim_deblur)
print('done training!')
# Out:
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# done data preprocessing!
# epoch:1,learning_rate_D:0.0001
# epoch:1,learning_rate_G:0.0001
# epochs: 1 5000/10000  degradation modeling stage: loss_D:0.249122 , loss_G: 0.828958 loss_G_cycle:0.119194 loss_feedback:0.000000
# epochs: 1 5000/10000  deblurring stage :loss_deblur:0.046524
# epochs: 1 10000/10000  degradation modeling stage: loss_D:0.205134 , loss_G: 0.850253 loss_G_cycle:0.100623 loss_feedback:0.000000
# epochs: 1 10000/10000  deblurring stage :loss_deblur:0.043237
# epoch:2,learning_rate_D:0.0001
# epoch:2,learning_rate_G:0.0001
# epochs: 2 5000/10000  degradation modeling stage: loss_D:0.210655 , loss_G: 0.817168 loss_G_cycle:0.096369 loss_feedback:0.004304
# epochs: 2 5000/10000  deblurring stage :loss_deblur:0.043283
# epochs: 2 10000/10000  degradation modeling stage: loss_D:0.205245 , loss_G: 0.829934 loss_G_cycle:0.093655 loss_feedback:0.004282
# epochs: 2 10000/10000  deblurring stage :loss_deblur:0.043040
# epoch:3,learning_rate_D:0.0001
# epoch:3,learning_rate_G:0.0001
# epochs: 3 5000/10000  degradation modeling stage: loss_D:0.199212 , loss_G: 0.845247 loss_G_cycle:0.092050 loss_feedback:0.004259
# epochs: 3 5000/10000  deblurring stage :loss_deblur:0.042781
# epochs: 3 10000/10000  degradation modeling stage: loss_D:0.186497 , loss_G: 0.902014 loss_G_cycle:0.091948 loss_feedback:0.004247
# epochs: 3 10000/10000  deblurring stage :loss_deblur:0.042677
# epoch:4,learning_rate_D:0.0001
# epoch:4,learning_rate_G:0.0001
# epochs: 4 5000/10000  degradation modeling stage: loss_D:0.180367 , loss_G: 0.928389 loss_G_cycle:0.090310 loss_feedback:0.004254
# epochs: 4 5000/10000  deblurring stage :loss_deblur:0.042761
# epochs: 4 10000/10000  degradation modeling stage: loss_D:0.184560 , loss_G: 0.895033 loss_G_cycle:0.089273 loss_feedback:0.004251
# epochs: 4 10000/10000  deblurring stage :loss_deblur:0.042715
# epoch:5,learning_rate_D:0.0001
# epoch:5,learning_rate_G:0.0001
# epochs: 5 5000/10000  degradation modeling stage: loss_D:0.183817 , loss_G: 0.924924 loss_G_cycle:0.087093 loss_feedback:0.004227
# epochs: 5 5000/10000  deblurring stage :loss_deblur:0.042472
# epochs: 5 10000/10000  degradation modeling stage: loss_D:0.184489 , loss_G: 0.939048 loss_G_cycle:0.087529 loss_feedback:0.004377
# epochs: 5 10000/10000  deblurring stage :loss_deblur:0.044070
# epoch:6,learning_rate_D:0.0001
# epoch:6,learning_rate_G:0.0001
# epochs: 6 5000/10000  degradation modeling stage: loss_D:0.179928 , loss_G: 0.918600 loss_G_cycle:0.089133 loss_feedback:0.004258
# epochs: 6 5000/10000  deblurring stage :loss_deblur:0.042752
# epochs: 6 10000/10000  degradation modeling stage: loss_D:0.177420 , loss_G: 0.941966 loss_G_cycle:0.086951 loss_feedback:0.004276
# epochs: 6 10000/10000  deblurring stage :loss_deblur:0.042881
# epoch:7,learning_rate_D:0.0001
# epoch:7,learning_rate_G:0.0001
# epochs: 7 5000/10000  degradation modeling stage: loss_D:0.200079 , loss_G: 0.899436 loss_G_cycle:0.087860 loss_feedback:0.004275
# epochs: 7 5000/10000  deblurring stage :loss_deblur:0.042924
# epochs: 7 10000/10000  degradation modeling stage: loss_D:0.189440 , loss_G: 0.854129 loss_G_cycle:0.083625 loss_feedback:0.004212
# epochs: 7 10000/10000  deblurring stage :loss_deblur:0.042220
# epoch:8,learning_rate_D:0.0001
# epoch:8,learning_rate_G:0.0001
# epochs: 8 5000/10000  degradation modeling stage: loss_D:0.178818 , loss_G: 0.893690 loss_G_cycle:0.085344 loss_feedback:0.004269
# epochs: 8 5000/10000  deblurring stage :loss_deblur:0.042856
# epochs: 8 10000/10000  degradation modeling stage: loss_D:0.170594 , loss_G: 0.944217 loss_G_cycle:0.086246 loss_feedback:0.004297
# epochs: 8 10000/10000  deblurring stage :loss_deblur:0.043053
# epoch:9,learning_rate_D:0.0001
# epoch:9,learning_rate_G:0.0001
# epochs: 9 5000/10000  degradation modeling stage: loss_D:0.172264 , loss_G: 0.950282 loss_G_cycle:0.084237 loss_feedback:0.004454
# epochs: 9 5000/10000  deblurring stage :loss_deblur:0.044674
# epochs: 9 10000/10000  degradation modeling stage: loss_D:0.165765 , loss_G: 0.956537 loss_G_cycle:0.085727 loss_feedback:0.004358
# epochs: 9 10000/10000  deblurring stage :loss_deblur:0.043749
# epoch:10,learning_rate_D:0.0001
# epoch:10,learning_rate_G:0.0001
# epochs: 10 5000/10000  degradation modeling stage: loss_D:0.164759 , loss_G: 0.975712 loss_G_cycle:0.085324 loss_feedback:0.004334
# epochs: 10 5000/10000  deblurring stage :loss_deblur:0.043527
# epochs: 10 10000/10000  degradation modeling stage: loss_D:0.164888 , loss_G: 0.968186 loss_G_cycle:0.084895 loss_feedback:0.004284
# epochs: 10 10000/10000  deblurring stage :loss_deblur:0.042998
# epoch:11,learning_rate_D:0.0001
# epoch:11,learning_rate_G:0.0001
# epochs: 11 5000/10000  degradation modeling stage: loss_D:0.192095 , loss_G: 0.990040 loss_G_cycle:0.086845 loss_feedback:0.004265
# epochs: 11 5000/10000  deblurring stage :loss_deblur:0.042796
# epochs: 11 10000/10000  degradation modeling stage: loss_D:0.187334 , loss_G: 0.880812 loss_G_cycle:0.080089 loss_feedback:0.004240
# epochs: 11 10000/10000  deblurring stage :loss_deblur:0.042528
# epoch:12,learning_rate_D:0.0001
# epoch:12,learning_rate_G:0.0001
# epochs: 12 5000/10000  degradation modeling stage: loss_D:0.167077 , loss_G: 0.958410 loss_G_cycle:0.084731 loss_feedback:0.004448
# epochs: 12 5000/10000  deblurring stage :loss_deblur:0.044614
# epochs: 12 10000/10000  degradation modeling stage: loss_D:0.165936 , loss_G: 0.975942 loss_G_cycle:0.086533 loss_feedback:0.004314
# epochs: 12 10000/10000  deblurring stage :loss_deblur:0.043316
# epoch:13,learning_rate_D:0.0001
# epoch:13,learning_rate_G:0.0001
# epochs: 13 5000/10000  degradation modeling stage: loss_D:0.163049 , loss_G: 0.957288 loss_G_cycle:0.083515 loss_feedback:0.004256
# epochs: 13 5000/10000  deblurring stage :loss_deblur:0.042645
# epochs: 13 10000/10000  degradation modeling stage: loss_D:0.164648 , loss_G: 0.959672 loss_G_cycle:0.083457 loss_feedback:0.004266
# epochs: 13 10000/10000  deblurring stage :loss_deblur:0.042771
# epoch:14,learning_rate_D:0.0001
# epoch:14,learning_rate_G:0.0001
# epochs: 14 5000/10000  degradation modeling stage: loss_D:0.165738 , loss_G: 0.966783 loss_G_cycle:0.083563 loss_feedback:0.004253
# epochs: 14 5000/10000  deblurring stage :loss_deblur:0.042660
# epochs: 14 10000/10000  degradation modeling stage: loss_D:0.169121 , loss_G: 0.958994 loss_G_cycle:0.082717 loss_feedback:0.004268
# epochs: 14 10000/10000  deblurring stage :loss_deblur:0.042830
# epoch:15,learning_rate_D:5e-05
# epoch:15,learning_rate_G:5e-05
# epochs: 15 5000/10000  degradation modeling stage: loss_D:0.157990 , loss_G: 0.951883 loss_G_cycle:0.080975 loss_feedback:0.004226
# epochs: 15 5000/10000  deblurring stage :loss_deblur:0.042304
# epochs: 15 10000/10000  degradation modeling stage: loss_D:0.161000 , loss_G: 0.963589 loss_G_cycle:0.081007 loss_feedback:0.004217
# epochs: 15 10000/10000  deblurring stage :loss_deblur:0.042221
# epoch:16,learning_rate_D:5e-05
# epoch:16,learning_rate_G:5e-05
# epochs: 16 5000/10000  degradation modeling stage: loss_D:0.156873 , loss_G: 0.979754 loss_G_cycle:0.082042 loss_feedback:0.004246
# epochs: 16 5000/10000  deblurring stage :loss_deblur:0.042534
# epochs: 16 10000/10000  degradation modeling stage: loss_D:0.156488 , loss_G: 0.991061 loss_G_cycle:0.081234 loss_feedback:0.004230
# epochs: 16 10000/10000  deblurring stage :loss_deblur:0.042369
# epoch:17,learning_rate_D:5e-05
# epoch:17,learning_rate_G:5e-05
# epochs: 17 5000/10000  degradation modeling stage: loss_D:0.158757 , loss_G: 0.980999 loss_G_cycle:0.080959 loss_feedback:0.004215
# epochs: 17 5000/10000  deblurring stage :loss_deblur:0.042197
# epochs: 17 10000/10000  degradation modeling stage: loss_D:0.159268 , loss_G: 0.992286 loss_G_cycle:0.081971 loss_feedback:0.004232
# epochs: 17 10000/10000  deblurring stage :loss_deblur:0.042400
# epoch:18,learning_rate_D:5e-05
# epoch:18,learning_rate_G:5e-05
# epochs: 18 5000/10000  degradation modeling stage: loss_D:0.157400 , loss_G: 0.987592 loss_G_cycle:0.080982 loss_feedback:0.004207
# epochs: 18 5000/10000  deblurring stage :loss_deblur:0.042137
# epochs: 18 10000/10000  degradation modeling stage: loss_D:0.143069 , loss_G: 1.091435 loss_G_cycle:0.085269 loss_feedback:0.004305
# epochs: 18 10000/10000  deblurring stage :loss_deblur:0.043141
# epoch:19,learning_rate_D:5e-05
# epoch:19,learning_rate_G:5e-05
# epochs: 19 5000/10000  degradation modeling stage: loss_D:0.155725 , loss_G: 1.002741 loss_G_cycle:0.081125 loss_feedback:0.004222
# epochs: 19 5000/10000  deblurring stage :loss_deblur:0.042271
# epochs: 19 10000/10000  degradation modeling stage: loss_D:0.156025 , loss_G: 1.002196 loss_G_cycle:0.081047 loss_feedback:0.004206
# epochs: 19 10000/10000  deblurring stage :loss_deblur:0.042112
# epoch:20,learning_rate_D:5e-05
# epoch:20,learning_rate_G:5e-05
# epochs: 20 5000/10000  degradation modeling stage: loss_D:0.157351 , loss_G: 0.997952 loss_G_cycle:0.080845 loss_feedback:0.004218
# epochs: 20 5000/10000  deblurring stage :loss_deblur:0.042231
# epochs: 20 10000/10000  degradation modeling stage: loss_D:0.154039 , loss_G: 1.002441 loss_G_cycle:0.081270 loss_feedback:0.004198
# epochs: 20 10000/10000  deblurring stage :loss_deblur:0.042038
# epoch:21,learning_rate_D:5e-05
# epoch:21,learning_rate_G:5e-05
# epochs: 21 5000/10000  degradation modeling stage: loss_D:0.152603 , loss_G: 1.011709 loss_G_cycle:0.081618 loss_feedback:0.004215
# epochs: 21 5000/10000  deblurring stage :loss_deblur:0.042244
# epochs: 21 10000/10000  degradation modeling stage: loss_D:0.157220 , loss_G: 1.013843 loss_G_cycle:0.082482 loss_feedback:0.004284
# epochs: 21 10000/10000  deblurring stage :loss_deblur:0.042851
# epoch:22,learning_rate_D:5e-05
# epoch:22,learning_rate_G:5e-05
# epochs: 22 5000/10000  degradation modeling stage: loss_D:0.154279 , loss_G: 1.001029 loss_G_cycle:0.081540 loss_feedback:0.004232
# epochs: 22 5000/10000  deblurring stage :loss_deblur:0.042408
# epochs: 22 10000/10000  degradation modeling stage: loss_D:0.154306 , loss_G: 1.009910 loss_G_cycle:0.081010 loss_feedback:0.004208
# epochs: 22 10000/10000  deblurring stage :loss_deblur:0.042138
# epoch:23,learning_rate_D:5e-05
# epoch:23,learning_rate_G:5e-05
# epochs: 23 5000/10000  degradation modeling stage: loss_D:0.155086 , loss_G: 1.074358 loss_G_cycle:0.083056 loss_feedback:0.004280
# epochs: 23 5000/10000  deblurring stage :loss_deblur:0.042877
# epochs: 23 10000/10000  degradation modeling stage: loss_D:0.129708 , loss_G: 1.172715 loss_G_cycle:0.085832 loss_feedback:0.004306
# epochs: 23 10000/10000  deblurring stage :loss_deblur:0.043204
# epoch:24,learning_rate_D:5e-05
# epoch:24,learning_rate_G:5e-05
# epochs: 24 5000/10000  degradation modeling stage: loss_D:0.151300 , loss_G: 1.009639 loss_G_cycle:0.081249 loss_feedback:0.004233
# epochs: 24 5000/10000  deblurring stage :loss_deblur:0.042405
# epochs: 24 10000/10000  degradation modeling stage: loss_D:0.148857 , loss_G: 1.067637 loss_G_cycle:0.082284 loss_feedback:0.004233
# epochs: 24 10000/10000  deblurring stage :loss_deblur:0.042405
# epoch:25,learning_rate_D:5e-05
# epoch:25,learning_rate_G:5e-05
# epochs: 25 5000/10000  degradation modeling stage: loss_D:0.121863 , loss_G: 1.241645 loss_G_cycle:0.084249 loss_feedback:0.004247
# epochs: 25 5000/10000  deblurring stage :loss_deblur:0.042579
# epochs: 25 10000/10000  degradation modeling stage: loss_D:0.153595 , loss_G: 0.990191 loss_G_cycle:0.081833 loss_feedback:0.004235
# epochs: 25 10000/10000  deblurring stage :loss_deblur:0.042437
# epoch:26,learning_rate_D:5e-05
# epoch:26,learning_rate_G:5e-05
# epochs: 26 5000/10000  degradation modeling stage: loss_D:0.151812 , loss_G: 1.020166 loss_G_cycle:0.081583 loss_feedback:0.004208
# epochs: 26 5000/10000  deblurring stage :loss_deblur:0.042143
# epochs: 26 10000/10000  degradation modeling stage: loss_D:0.151649 , loss_G: 1.025358 loss_G_cycle:0.081512 loss_feedback:0.004223
# epochs: 26 10000/10000  deblurring stage :loss_deblur:0.042297
# epoch:27,learning_rate_D:5e-05
# epoch:27,learning_rate_G:5e-05
# epochs: 27 5000/10000  degradation modeling stage: loss_D:0.152850 , loss_G: 1.015415 loss_G_cycle:0.081543 loss_feedback:0.004210
# epochs: 27 5000/10000  deblurring stage :loss_deblur:0.042178
# epochs: 27 10000/10000  degradation modeling stage: loss_D:0.151807 , loss_G: 1.027399 loss_G_cycle:0.081332 loss_feedback:0.004216
# epochs: 27 10000/10000  deblurring stage :loss_deblur:0.042247
# epoch:28,learning_rate_D:5e-05
# epoch:28,learning_rate_G:5e-05
# epochs: 28 5000/10000  degradation modeling stage: loss_D:0.149459 , loss_G: 1.033026 loss_G_cycle:0.081791 loss_feedback:0.004230
# epochs: 28 5000/10000  deblurring stage :loss_deblur:0.042427
# epochs: 28 10000/10000  degradation modeling stage: loss_D:0.155532 , loss_G: 1.030937 loss_G_cycle:0.083358 loss_feedback:0.004279
# epochs: 28 10000/10000  deblurring stage :loss_deblur:0.042900
# epoch:29,learning_rate_D:5e-05
# epoch:29,learning_rate_G:5e-05
# epochs: 29 5000/10000  degradation modeling stage: loss_D:0.122881 , loss_G: 1.235919 loss_G_cycle:0.084668 loss_feedback:0.004257
# epochs: 29 5000/10000  deblurring stage :loss_deblur:0.042729
# epochs: 29 10000/10000  degradation modeling stage: loss_D:0.148076 , loss_G: 1.019421 loss_G_cycle:0.082688 loss_feedback:0.004248
# epochs: 29 10000/10000  deblurring stage :loss_deblur:0.042557
# epoch:30,learning_rate_D:2.5e-05
# epoch:30,learning_rate_G:2.5e-05
# epochs: 30 5000/10000  degradation modeling stage: loss_D:0.144121 , loss_G: 1.037679 loss_G_cycle:0.080598 loss_feedback:0.004218
# epochs: 30 5000/10000  deblurring stage :loss_deblur:0.042196
# epochs: 30 10000/10000  degradation modeling stage: loss_D:0.138856 , loss_G: 1.036193 loss_G_cycle:0.081093 loss_feedback:0.004198
# epochs: 30 10000/10000  deblurring stage :loss_deblur:0.042007
# epoch:31,learning_rate_D:2.5e-05
# epoch:31,learning_rate_G:2.5e-05
# epochs: 31 5000/10000  degradation modeling stage: loss_D:0.140408 , loss_G: 1.039617 loss_G_cycle:0.080816 loss_feedback:0.004201
# epochs: 31 5000/10000  deblurring stage :loss_deblur:0.042039
# epochs: 31 10000/10000  degradation modeling stage: loss_D:0.144017 , loss_G: 1.046621 loss_G_cycle:0.080765 loss_feedback:0.004205
# epochs: 31 10000/10000  deblurring stage :loss_deblur:0.042085
# epoch:32,learning_rate_D:2.5e-05
# epoch:32,learning_rate_G:2.5e-05
# epochs: 32 5000/10000  degradation modeling stage: loss_D:0.142277 , loss_G: 1.052221 loss_G_cycle:0.081006 loss_feedback:0.004210
# epochs: 32 5000/10000  deblurring stage :loss_deblur:0.042128
# epochs: 32 10000/10000  degradation modeling stage: loss_D:0.129128 , loss_G: 1.146264 loss_G_cycle:0.083506 loss_feedback:0.004235
# epochs: 32 10000/10000  deblurring stage :loss_deblur:0.042392
# epoch:33,learning_rate_D:2.5e-05
# epoch:33,learning_rate_G:2.5e-05
# epochs: 33 5000/10000  degradation modeling stage: loss_D:0.112543 , loss_G: 1.278722 loss_G_cycle:0.084041 loss_feedback:0.004233
# epochs: 33 5000/10000  deblurring stage :loss_deblur:0.042401
# epochs: 33 10000/10000  degradation modeling stage: loss_D:0.135874 , loss_G: 1.057303 loss_G_cycle:0.081858 loss_feedback:0.004233
# epochs: 33 10000/10000  deblurring stage :loss_deblur:0.042367
# epoch:34,learning_rate_D:2.5e-05
# epoch:34,learning_rate_G:2.5e-05
# epochs: 34 5000/10000  degradation modeling stage: loss_D:0.140299 , loss_G: 1.065404 loss_G_cycle:0.081237 loss_feedback:0.004202
# epochs: 34 5000/10000  deblurring stage :loss_deblur:0.042064
# epochs: 34 10000/10000  degradation modeling stage: loss_D:0.138886 , loss_G: 1.067366 loss_G_cycle:0.080921 loss_feedback:0.004207
# epochs: 34 10000/10000  deblurring stage :loss_deblur:0.042100
# epoch:35,learning_rate_D:2.5e-05
# epoch:35,learning_rate_G:2.5e-05
# epochs: 35 5000/10000  degradation modeling stage: loss_D:0.138903 , loss_G: 1.064801 loss_G_cycle:0.080968 loss_feedback:0.004205
# epochs: 35 5000/10000  deblurring stage :loss_deblur:0.042089
# epochs: 35 10000/10000  degradation modeling stage: loss_D:0.114518 , loss_G: 1.291490 loss_G_cycle:0.084807 loss_feedback:0.004263
# epochs: 35 10000/10000  deblurring stage :loss_deblur:0.042688
# epoch:36,learning_rate_D:2.5e-05
# epoch:36,learning_rate_G:2.5e-05
# epochs: 36 5000/10000  degradation modeling stage: loss_D:0.110644 , loss_G: 1.280621 loss_G_cycle:0.084181 loss_feedback:0.004238
# epochs: 36 5000/10000  deblurring stage :loss_deblur:0.042459
# epochs: 36 10000/10000  degradation modeling stage: loss_D:0.123587 , loss_G: 1.160744 loss_G_cycle:0.083891 loss_feedback:0.004241
# epochs: 36 10000/10000  deblurring stage :loss_deblur:0.042501
# epoch:37,learning_rate_D:2.5e-05
# epoch:37,learning_rate_G:2.5e-05
# epochs: 37 5000/10000  degradation modeling stage: loss_D:0.139493 , loss_G: 1.060859 loss_G_cycle:0.082126 loss_feedback:0.004229
# epochs: 37 5000/10000  deblurring stage :loss_deblur:0.042344
# epochs: 37 10000/10000  degradation modeling stage: loss_D:0.139539 , loss_G: 1.077010 loss_G_cycle:0.081420 loss_feedback:0.004203
# epochs: 37 10000/10000  deblurring stage :loss_deblur:0.042076
# epoch:38,learning_rate_D:2.5e-05
# epoch:38,learning_rate_G:2.5e-05
# epochs: 38 5000/10000  degradation modeling stage: loss_D:0.138187 , loss_G: 1.079357 loss_G_cycle:0.081359 loss_feedback:0.004209
# epochs: 38 5000/10000  deblurring stage :loss_deblur:0.042127
# epochs: 38 10000/10000  degradation modeling stage: loss_D:0.139242 , loss_G: 1.081017 loss_G_cycle:0.081419 loss_feedback:0.004193
# epochs: 38 10000/10000  deblurring stage :loss_deblur:0.041971
# epoch:39,learning_rate_D:2.5e-05
# epoch:39,learning_rate_G:2.5e-05
# epochs: 39 5000/10000  degradation modeling stage: loss_D:0.138110 , loss_G: 1.074992 loss_G_cycle:0.081719 loss_feedback:0.004207
# epochs: 39 5000/10000  deblurring stage :loss_deblur:0.042119
# epochs: 39 10000/10000  degradation modeling stage: loss_D:0.137879 , loss_G: 1.081270 loss_G_cycle:0.081579 loss_feedback:0.004203
# epochs: 39 10000/10000  deblurring stage :loss_deblur:0.042069
# epoch:40,learning_rate_D:2.5e-05
# epoch:40,learning_rate_G:2.5e-05
# epochs: 40 5000/10000  degradation modeling stage: loss_D:0.138861 , loss_G: 1.074943 loss_G_cycle:0.081395 loss_feedback:0.004207
# epochs: 40 5000/10000  deblurring stage :loss_deblur:0.042105
# epochs: 40 10000/10000  degradation modeling stage: loss_D:0.135209 , loss_G: 1.099768 loss_G_cycle:0.081469 loss_feedback:0.004189
# epochs: 40 10000/10000  deblurring stage :loss_deblur:0.041933
# epoch:41,learning_rate_D:2.5e-05
# epoch:41,learning_rate_G:2.5e-05
# epochs: 41 5000/10000  degradation modeling stage: loss_D:0.138131 , loss_G: 1.094316 loss_G_cycle:0.081168 loss_feedback:0.004191
# epochs: 41 5000/10000  deblurring stage :loss_deblur:0.041954
# epochs: 41 10000/10000  degradation modeling stage: loss_D:0.139407 , loss_G: 1.079537 loss_G_cycle:0.081601 loss_feedback:0.004216
# epochs: 41 10000/10000  deblurring stage :loss_deblur:0.042220
# epoch:42,learning_rate_D:2.5e-05
# epoch:42,learning_rate_G:2.5e-05
# epochs: 42 5000/10000  degradation modeling stage: loss_D:0.134961 , loss_G: 1.095713 loss_G_cycle:0.081421 loss_feedback:0.004213
# epochs: 42 5000/10000  deblurring stage :loss_deblur:0.042177
# epochs: 42 10000/10000  degradation modeling stage: loss_D:0.135121 , loss_G: 1.097311 loss_G_cycle:0.081566 loss_feedback:0.004191
# epochs: 42 10000/10000  deblurring stage :loss_deblur:0.041955
# epoch:43,learning_rate_D:2.5e-05
# epoch:43,learning_rate_G:2.5e-05
# epochs: 43 5000/10000  degradation modeling stage: loss_D:0.137487 , loss_G: 1.100216 loss_G_cycle:0.081510 loss_feedback:0.004202
# epochs: 43 5000/10000  deblurring stage :loss_deblur:0.042064
# epochs: 43 10000/10000  degradation modeling stage: loss_D:0.115240 , loss_G: 1.256526 loss_G_cycle:0.084632 loss_feedback:0.004260
# epochs: 43 10000/10000  deblurring stage :loss_deblur:0.042675
# epoch:44,learning_rate_D:2.5e-05
# epoch:44,learning_rate_G:2.5e-05
# epochs: 44 5000/10000  degradation modeling stage: loss_D:0.107657 , loss_G: 1.312352 loss_G_cycle:0.084621 loss_feedback:0.004230
# epochs: 44 5000/10000  deblurring stage :loss_deblur:0.042384
# epochs: 44 10000/10000  degradation modeling stage: loss_D:0.100896 , loss_G: 1.330387 loss_G_cycle:0.084626 loss_feedback:0.004219
# epochs: 44 10000/10000  deblurring stage :loss_deblur:0.042263
# epoch:45,learning_rate_D:1.25e-05
# epoch:45,learning_rate_G:1.25e-05
# epochs: 45 5000/10000  degradation modeling stage: loss_D:0.103578 , loss_G: 1.314732 loss_G_cycle:0.083491 loss_feedback:0.004223
# epochs: 45 5000/10000  deblurring stage :loss_deblur:0.042234
# epochs: 45 10000/10000  degradation modeling stage: loss_D:0.108931 , loss_G: 1.221908 loss_G_cycle:0.084611 loss_feedback:0.004237
# epochs: 45 10000/10000  deblurring stage :loss_deblur:0.042398
# epoch:46,learning_rate_D:1.25e-05
# epoch:46,learning_rate_G:1.25e-05
# epochs: 46 5000/10000  degradation modeling stage: loss_D:0.129882 , loss_G: 1.085817 loss_G_cycle:0.082633 loss_feedback:0.004235
# epochs: 46 5000/10000  deblurring stage :loss_deblur:0.042386
# epochs: 46 10000/10000  degradation modeling stage: loss_D:0.128843 , loss_G: 1.117969 loss_G_cycle:0.082256 loss_feedback:0.004218
# epochs: 46 10000/10000  deblurring stage :loss_deblur:0.042207
# epoch:47,learning_rate_D:1.25e-05
# epoch:47,learning_rate_G:1.25e-05
# epochs: 47 5000/10000  degradation modeling stage: loss_D:0.131259 , loss_G: 1.104336 loss_G_cycle:0.081986 loss_feedback:0.004212
# epochs: 47 5000/10000  deblurring stage :loss_deblur:0.042146
# epochs: 47 10000/10000  degradation modeling stage: loss_D:0.130188 , loss_G: 1.117404 loss_G_cycle:0.081905 loss_feedback:0.004201
# epochs: 47 10000/10000  deblurring stage :loss_deblur:0.042031
# epoch:48,learning_rate_D:1.25e-05
# epoch:48,learning_rate_G:1.25e-05
# epochs: 48 5000/10000  degradation modeling stage: loss_D:0.129838 , loss_G: 1.123991 loss_G_cycle:0.081549 loss_feedback:0.004199
# epochs: 48 5000/10000  deblurring stage :loss_deblur:0.042013
# epochs: 48 10000/10000  degradation modeling stage: loss_D:0.129524 , loss_G: 1.110683 loss_G_cycle:0.081730 loss_feedback:0.004196
# epochs: 48 10000/10000  deblurring stage :loss_deblur:0.041969
# epoch:49,learning_rate_D:1.25e-05
# epoch:49,learning_rate_G:1.25e-05
# epochs: 49 5000/10000  degradation modeling stage: loss_D:0.130205 , loss_G: 1.114972 loss_G_cycle:0.081291 loss_feedback:0.004190
# epochs: 49 5000/10000  deblurring stage :loss_deblur:0.041916
# epochs: 49 10000/10000  degradation modeling stage: loss_D:0.127855 , loss_G: 1.122479 loss_G_cycle:0.082013 loss_feedback:0.004203
# epochs: 49 10000/10000  deblurring stage :loss_deblur:0.042049
# epoch:50,learning_rate_D:1.25e-05
# epoch:50,learning_rate_G:1.25e-05
# epochs: 50 5000/10000  degradation modeling stage: loss_D:0.129576 , loss_G: 1.128852 loss_G_cycle:0.081687 loss_feedback:0.004198
# epochs: 50 5000/10000  deblurring stage :loss_deblur:0.042001
# epochs: 50 10000/10000  degradation modeling stage: loss_D:0.128616 , loss_G: 1.126995 loss_G_cycle:0.081369 loss_feedback:0.004196
# epochs: 50 10000/10000  deblurring stage :loss_deblur:0.041975
# epoch:51,learning_rate_D:1.25e-05
# epoch:51,learning_rate_G:1.25e-05
# epochs: 51 5000/10000  degradation modeling stage: loss_D:0.129462 , loss_G: 1.131789 loss_G_cycle:0.081592 loss_feedback:0.004192
# epochs: 51 5000/10000  deblurring stage :loss_deblur:0.041946
# epochs: 51 10000/10000  degradation modeling stage: loss_D:0.126537 , loss_G: 1.128472 loss_G_cycle:0.081799 loss_feedback:0.004201
# epochs: 51 10000/10000  deblurring stage :loss_deblur:0.042034
# epoch:52,learning_rate_D:1.25e-05
# epoch:52,learning_rate_G:1.25e-05
# epochs: 52 5000/10000  degradation modeling stage: loss_D:0.127466 , loss_G: 1.141700 loss_G_cycle:0.081261 loss_feedback:0.004182
# epochs: 52 5000/10000  deblurring stage :loss_deblur:0.041835
# epochs: 52 10000/10000  degradation modeling stage: loss_D:0.129972 , loss_G: 1.135841 loss_G_cycle:0.081765 loss_feedback:0.004205
# epochs: 52 10000/10000  deblurring stage :loss_deblur:0.042073
# epoch:53,learning_rate_D:1.25e-05
# epoch:53,learning_rate_G:1.25e-05
# epochs: 53 5000/10000  degradation modeling stage: loss_D:0.126806 , loss_G: 1.133272 loss_G_cycle:0.081785 loss_feedback:0.004191
# epochs: 53 5000/10000  deblurring stage :loss_deblur:0.041932
# epochs: 53 10000/10000  degradation modeling stage: loss_D:0.126013 , loss_G: 1.131222 loss_G_cycle:0.081878 loss_feedback:0.004193
# epochs: 53 10000/10000  deblurring stage :loss_deblur:0.041953
# epoch:54,learning_rate_D:1.25e-05
# epoch:54,learning_rate_G:1.25e-05
# epochs: 54 5000/10000  degradation modeling stage: loss_D:0.128844 , loss_G: 1.130889 loss_G_cycle:0.081903 loss_feedback:0.004201
# epochs: 54 5000/10000  deblurring stage :loss_deblur:0.042034
# epochs: 54 10000/10000  degradation modeling stage: loss_D:0.126045 , loss_G: 1.145097 loss_G_cycle:0.081341 loss_feedback:0.004180
# epochs: 54 10000/10000  deblurring stage :loss_deblur:0.041812
# epoch:55,learning_rate_D:1.25e-05
# epoch:55,learning_rate_G:1.25e-05
# epochs: 55 5000/10000  degradation modeling stage: loss_D:0.125656 , loss_G: 1.144221 loss_G_cycle:0.081583 loss_feedback:0.004189
# epochs: 55 5000/10000  deblurring stage :loss_deblur:0.041913
# epochs: 55 10000/10000  degradation modeling stage: loss_D:0.124608 , loss_G: 1.150127 loss_G_cycle:0.081705 loss_feedback:0.004191
# epochs: 55 10000/10000  deblurring stage :loss_deblur:0.041930
# epoch:56,learning_rate_D:1.25e-05
# epoch:56,learning_rate_G:1.25e-05
# epochs: 56 5000/10000  degradation modeling stage: loss_D:0.125858 , loss_G: 1.141222 loss_G_cycle:0.082036 loss_feedback:0.004199
# epochs: 56 5000/10000  deblurring stage :loss_deblur:0.042026
# epochs: 56 10000/10000  degradation modeling stage: loss_D:0.126560 , loss_G: 1.146268 loss_G_cycle:0.081945 loss_feedback:0.004195
# epochs: 56 10000/10000  deblurring stage :loss_deblur:0.041981
# epoch:57,learning_rate_D:1.25e-05
# epoch:57,learning_rate_G:1.25e-05
# epochs: 57 5000/10000  degradation modeling stage: loss_D:0.124775 , loss_G: 1.141225 loss_G_cycle:0.081826 loss_feedback:0.004208
# epochs: 57 5000/10000  deblurring stage :loss_deblur:0.042110
# epochs: 57 10000/10000  degradation modeling stage: loss_D:0.127127 , loss_G: 1.141655 loss_G_cycle:0.082141 loss_feedback:0.004201
# epochs: 57 10000/10000  deblurring stage :loss_deblur:0.042044
# epoch:58,learning_rate_D:1.25e-05
# epoch:58,learning_rate_G:1.25e-05
# epochs: 58 5000/10000  degradation modeling stage: loss_D:0.122677 , loss_G: 1.156711 loss_G_cycle:0.082055 loss_feedback:0.004194
# epochs: 58 5000/10000  deblurring stage :loss_deblur:0.041963
# epochs: 58 10000/10000  degradation modeling stage: loss_D:0.129612 , loss_G: 1.142316 loss_G_cycle:0.081989 loss_feedback:0.004200
# epochs: 58 10000/10000  deblurring stage :loss_deblur:0.042033
# epoch:59,learning_rate_D:1.25e-05
# epoch:59,learning_rate_G:1.25e-05
# epochs: 59 5000/10000  degradation modeling stage: loss_D:0.129299 , loss_G: 1.141882 loss_G_cycle:0.081930 loss_feedback:0.004192
# epochs: 59 5000/10000  deblurring stage :loss_deblur:0.041943
# epochs: 59 10000/10000  degradation modeling stage: loss_D:0.124665 , loss_G: 1.151528 loss_G_cycle:0.082042 loss_feedback:0.004206
# epochs: 59 10000/10000  deblurring stage :loss_deblur:0.042088
# epoch:60,learning_rate_D:6.25e-06
# epoch:60,learning_rate_G:6.25e-06
# epochs: 60 5000/10000  degradation modeling stage: loss_D:0.122925 , loss_G: 1.178749 loss_G_cycle:0.081565 loss_feedback:0.004200
# epochs: 60 5000/10000  deblurring stage :loss_deblur:0.042010
# epochs: 60 10000/10000  degradation modeling stage: loss_D:0.119843 , loss_G: 1.168508 loss_G_cycle:0.081839 loss_feedback:0.004189
# epochs: 60 10000/10000  deblurring stage :loss_deblur:0.041896
# epoch:61,learning_rate_D:6.25e-06
# epoch:61,learning_rate_G:6.25e-06
# epochs: 61 5000/10000  degradation modeling stage: loss_D:0.124134 , loss_G: 1.170100 loss_G_cycle:0.082006 loss_feedback:0.004189
# epochs: 61 5000/10000  deblurring stage :loss_deblur:0.041903
# epochs: 61 10000/10000  degradation modeling stage: loss_D:0.120785 , loss_G: 1.166613 loss_G_cycle:0.082056 loss_feedback:0.004206
# epochs: 61 10000/10000  deblurring stage :loss_deblur:0.042071
# epoch:62,learning_rate_D:6.25e-06
# epoch:62,learning_rate_G:6.25e-06
# epochs: 62 5000/10000  degradation modeling stage: loss_D:0.123312 , loss_G: 1.165605 loss_G_cycle:0.081930 loss_feedback:0.004200
# epochs: 62 5000/10000  deblurring stage :loss_deblur:0.042017
# epochs: 62 10000/10000  degradation modeling stage: loss_D:0.123562 , loss_G: 1.174316 loss_G_cycle:0.081792 loss_feedback:0.004193
# epochs: 62 10000/10000  deblurring stage :loss_deblur:0.041946
# epoch:63,learning_rate_D:6.25e-06
# epoch:63,learning_rate_G:6.25e-06
# epochs: 63 5000/10000  degradation modeling stage: loss_D:0.122190 , loss_G: 1.163421 loss_G_cycle:0.082177 loss_feedback:0.004193
# epochs: 63 5000/10000  deblurring stage :loss_deblur:0.041941
# epochs: 63 10000/10000  degradation modeling stage: loss_D:0.125853 , loss_G: 1.164089 loss_G_cycle:0.081751 loss_feedback:0.004201
# epochs: 63 10000/10000  deblurring stage :loss_deblur:0.042025
# epoch:64,learning_rate_D:6.25e-06
# epoch:64,learning_rate_G:6.25e-06
# epochs: 64 5000/10000  degradation modeling stage: loss_D:0.122825 , loss_G: 1.157742 loss_G_cycle:0.081876 loss_feedback:0.004200
# epochs: 64 5000/10000  deblurring stage :loss_deblur:0.042014
# epochs: 64 10000/10000  degradation modeling stage: loss_D:0.121501 , loss_G: 1.163483 loss_G_cycle:0.081987 loss_feedback:0.004188
# epochs: 64 10000/10000  deblurring stage :loss_deblur:0.041899
# epoch:65,learning_rate_D:6.25e-06
# epoch:65,learning_rate_G:6.25e-06
# epochs: 65 5000/10000  degradation modeling stage: loss_D:0.121892 , loss_G: 1.168275 loss_G_cycle:0.081898 loss_feedback:0.004198
# epochs: 65 5000/10000  deblurring stage :loss_deblur:0.041999
# epochs: 65 10000/10000  degradation modeling stage: loss_D:0.121348 , loss_G: 1.167557 loss_G_cycle:0.081997 loss_feedback:0.004190
# epochs: 65 10000/10000  deblurring stage :loss_deblur:0.041913
# epoch:66,learning_rate_D:6.25e-06
# epoch:66,learning_rate_G:6.25e-06
# epochs: 66 5000/10000  degradation modeling stage: loss_D:0.123089 , loss_G: 1.171072 loss_G_cycle:0.082072 loss_feedback:0.004206
# epochs: 66 5000/10000  deblurring stage :loss_deblur:0.042074
# epochs: 66 10000/10000  degradation modeling stage: loss_D:0.121700 , loss_G: 1.151830 loss_G_cycle:0.082033 loss_feedback:0.004193
# epochs: 66 10000/10000  deblurring stage :loss_deblur:0.041946
# epoch:67,learning_rate_D:6.25e-06
# epoch:67,learning_rate_G:6.25e-06
# epochs: 67 5000/10000  degradation modeling stage: loss_D:0.121091 , loss_G: 1.169551 loss_G_cycle:0.082090 loss_feedback:0.004197
# epochs: 67 5000/10000  deblurring stage :loss_deblur:0.041983
# epochs: 67 10000/10000  degradation modeling stage: loss_D:0.121450 , loss_G: 1.182378 loss_G_cycle:0.082081 loss_feedback:0.004192
# epochs: 67 10000/10000  deblurring stage :loss_deblur:0.041937
# epoch:68,learning_rate_D:6.25e-06
# epoch:68,learning_rate_G:6.25e-06
# epochs: 68 5000/10000  degradation modeling stage: loss_D:0.122820 , loss_G: 1.171181 loss_G_cycle:0.082126 loss_feedback:0.004203
# epochs: 68 5000/10000  deblurring stage :loss_deblur:0.042045
# epochs: 68 10000/10000  degradation modeling stage: loss_D:0.120657 , loss_G: 1.175024 loss_G_cycle:0.081878 loss_feedback:0.004189
# epochs: 68 10000/10000  deblurring stage :loss_deblur:0.041901
# epoch:69,learning_rate_D:6.25e-06
# epoch:69,learning_rate_G:6.25e-06
# epochs: 69 5000/10000  degradation modeling stage: loss_D:0.116517 , loss_G: 1.203196 loss_G_cycle:0.083135 loss_feedback:0.004232
# epochs: 69 5000/10000  deblurring stage :loss_deblur:0.042350
# epochs: 69 10000/10000  degradation modeling stage: loss_D:0.094347 , loss_G: 1.384380 loss_G_cycle:0.085236 loss_feedback:0.004245
# epochs: 69 10000/10000  deblurring stage :loss_deblur:0.042451
# epoch:70,learning_rate_D:6.25e-06
# epoch:70,learning_rate_G:6.25e-06
# epochs: 70 5000/10000  degradation modeling stage: loss_D:0.095922 , loss_G: 1.395657 loss_G_cycle:0.083551 loss_feedback:0.004211
# epochs: 70 5000/10000  deblurring stage :loss_deblur:0.042103
# epochs: 70 10000/10000  degradation modeling stage: loss_D:0.098503 , loss_G: 1.359469 loss_G_cycle:0.083634 loss_feedback:0.004209
# epochs: 70 10000/10000  deblurring stage :loss_deblur:0.042094
# epoch:71,learning_rate_D:6.25e-06
# epoch:71,learning_rate_G:6.25e-06
# epochs: 71 5000/10000  degradation modeling stage: loss_D:0.097638 , loss_G: 1.368910 loss_G_cycle:0.083332 loss_feedback:0.004200
# epochs: 71 5000/10000  deblurring stage :loss_deblur:0.041995
# epochs: 71 10000/10000  degradation modeling stage: loss_D:0.093162 , loss_G: 1.383882 loss_G_cycle:0.084759 loss_feedback:0.004211
# epochs: 71 10000/10000  deblurring stage :loss_deblur:0.042114
# epoch:72,learning_rate_D:6.25e-06
# epoch:72,learning_rate_G:6.25e-06
# epochs: 72 5000/10000  degradation modeling stage: loss_D:0.098434 , loss_G: 1.375414 loss_G_cycle:0.084346 loss_feedback:0.004209
# epochs: 72 5000/10000  deblurring stage :loss_deblur:0.042094
# epochs: 72 10000/10000  degradation modeling stage: loss_D:0.092082 , loss_G: 1.384903 loss_G_cycle:0.084547 loss_feedback:0.004208
# epochs: 72 10000/10000  deblurring stage :loss_deblur:0.042078
# epoch:73,learning_rate_D:6.25e-06
# epoch:73,learning_rate_G:6.25e-06
# epochs: 73 5000/10000  degradation modeling stage: loss_D:0.092485 , loss_G: 1.385857 loss_G_cycle:0.084312 loss_feedback:0.004196
# epochs: 73 5000/10000  deblurring stage :loss_deblur:0.041967
# epochs: 73 10000/10000  degradation modeling stage: loss_D:0.093503 , loss_G: 1.397514 loss_G_cycle:0.084113 loss_feedback:0.004203
# epochs: 73 10000/10000  deblurring stage :loss_deblur:0.042035
# epoch:74,learning_rate_D:6.25e-06
# epoch:74,learning_rate_G:6.25e-06
# epochs: 74 5000/10000  degradation modeling stage: loss_D:0.091616 , loss_G: 1.395666 loss_G_cycle:0.084510 loss_feedback:0.004195
# epochs: 74 5000/10000  deblurring stage :loss_deblur:0.041953
# epochs: 74 10000/10000  degradation modeling stage: loss_D:0.097969 , loss_G: 1.279697 loss_G_cycle:0.086832 loss_feedback:0.004267
# epochs: 74 10000/10000  deblurring stage :loss_deblur:0.042731
# epoch:75,learning_rate_D:3.125e-06
# epoch:75,learning_rate_G:3.125e-06
# epochs: 75 5000/10000  degradation modeling stage: loss_D:0.113415 , loss_G: 1.180445 loss_G_cycle:0.085730 loss_feedback:0.004256
# epochs: 75 5000/10000  deblurring stage :loss_deblur:0.042562
# epochs: 75 10000/10000  degradation modeling stage: loss_D:0.115261 , loss_G: 1.200412 loss_G_cycle:0.084371 loss_feedback:0.004202
# epochs: 75 10000/10000  deblurring stage :loss_deblur:0.042026
# epoch:76,learning_rate_D:3.125e-06
# epoch:76,learning_rate_G:3.125e-06
# epochs: 76 5000/10000  degradation modeling stage: loss_D:0.118139 , loss_G: 1.192640 loss_G_cycle:0.083121 loss_feedback:0.004184
# epochs: 76 5000/10000  deblurring stage :loss_deblur:0.041842
# epochs: 76 10000/10000  degradation modeling stage: loss_D:0.114419 , loss_G: 1.221680 loss_G_cycle:0.083518 loss_feedback:0.004184
# epochs: 76 10000/10000  deblurring stage :loss_deblur:0.041844
# epoch:77,learning_rate_D:3.125e-06
# epoch:77,learning_rate_G:3.125e-06
# epochs: 77 5000/10000  degradation modeling stage: loss_D:0.115131 , loss_G: 1.216039 loss_G_cycle:0.083145 loss_feedback:0.004190
# epochs: 77 5000/10000  deblurring stage :loss_deblur:0.041906
# epochs: 77 10000/10000  degradation modeling stage: loss_D:0.115176 , loss_G: 1.207745 loss_G_cycle:0.083129 loss_feedback:0.004178
# epochs: 77 10000/10000  deblurring stage :loss_deblur:0.041783
# epoch:78,learning_rate_D:3.125e-06
# epoch:78,learning_rate_G:3.125e-06
# epochs: 78 5000/10000  degradation modeling stage: loss_D:0.114244 , loss_G: 1.201112 loss_G_cycle:0.083204 loss_feedback:0.004183
# epochs: 78 5000/10000  deblurring stage :loss_deblur:0.041836
# epochs: 78 10000/10000  degradation modeling stage: loss_D:0.117722 , loss_G: 1.174296 loss_G_cycle:0.083314 loss_feedback:0.004183
# epochs: 78 10000/10000  deblurring stage :loss_deblur:0.041828
# epoch:79,learning_rate_D:3.125e-06
# epoch:79,learning_rate_G:3.125e-06
# epochs: 79 5000/10000  degradation modeling stage: loss_D:0.113842 , loss_G: 1.210789 loss_G_cycle:0.082918 loss_feedback:0.004194
# epochs: 79 5000/10000  deblurring stage :loss_deblur:0.041947
# epochs: 79 10000/10000  degradation modeling stage: loss_D:0.116392 , loss_G: 1.180872 loss_G_cycle:0.083144 loss_feedback:0.004185
# epochs: 79 10000/10000  deblurring stage :loss_deblur:0.041848
# epoch:80,learning_rate_D:3.125e-06
# epoch:80,learning_rate_G:3.125e-06
# epochs: 80 5000/10000  degradation modeling stage: loss_D:0.113818 , loss_G: 1.214105 loss_G_cycle:0.082741 loss_feedback:0.004187
# epochs: 80 5000/10000  deblurring stage :loss_deblur:0.041874
# epochs: 80 10000/10000  degradation modeling stage: loss_D:0.114419 , loss_G: 1.215459 loss_G_cycle:0.083278 loss_feedback:0.004212
# epochs: 80 10000/10000  deblurring stage :loss_deblur:0.042124
# epoch:81,learning_rate_D:3.125e-06
# epoch:81,learning_rate_G:3.125e-06
# epochs: 81 5000/10000  degradation modeling stage: loss_D:0.116203 , loss_G: 1.181685 loss_G_cycle:0.083008 loss_feedback:0.004187
# epochs: 81 5000/10000  deblurring stage :loss_deblur:0.041875
# epochs: 81 10000/10000  degradation modeling stage: loss_D:0.114089 , loss_G: 1.214884 loss_G_cycle:0.083391 loss_feedback:0.004224
# epochs: 81 10000/10000  deblurring stage :loss_deblur:0.042251
# epoch:82,learning_rate_D:3.125e-06
# epoch:82,learning_rate_G:3.125e-06
# epochs: 82 5000/10000  degradation modeling stage: loss_D:0.123152 , loss_G: 1.174958 loss_G_cycle:0.083404 loss_feedback:0.004220
# epochs: 82 5000/10000  deblurring stage :loss_deblur:0.042210
# epochs: 82 10000/10000  degradation modeling stage: loss_D:0.114133 , loss_G: 1.211110 loss_G_cycle:0.083155 loss_feedback:0.004210
# epochs: 82 10000/10000  deblurring stage :loss_deblur:0.042108
# epoch:83,learning_rate_D:3.125e-06
# epoch:83,learning_rate_G:3.125e-06
# epochs: 83 5000/10000  degradation modeling stage: loss_D:0.118372 , loss_G: 1.197391 loss_G_cycle:0.082782 loss_feedback:0.004203
# epochs: 83 5000/10000  deblurring stage :loss_deblur:0.042039
# epochs: 83 10000/10000  degradation modeling stage: loss_D:0.118041 , loss_G: 1.207155 loss_G_cycle:0.082702 loss_feedback:0.004197
# epochs: 83 10000/10000  deblurring stage :loss_deblur:0.041980
# epoch:84,learning_rate_D:3.125e-06
# epoch:84,learning_rate_G:3.125e-06
# epochs: 84 5000/10000  degradation modeling stage: loss_D:0.116893 , loss_G: 1.191280 loss_G_cycle:0.082646 loss_feedback:0.004204
# epochs: 84 5000/10000  deblurring stage :loss_deblur:0.042047
# epochs: 84 10000/10000  degradation modeling stage: loss_D:0.112916 , loss_G: 1.213433 loss_G_cycle:0.082507 loss_feedback:0.004199
# epochs: 84 10000/10000  deblurring stage :loss_deblur:0.041997
# epoch:85,learning_rate_D:3.125e-06
# epoch:85,learning_rate_G:3.125e-06
# epochs: 85 5000/10000  degradation modeling stage: loss_D:0.117316 , loss_G: 1.218725 loss_G_cycle:0.082428 loss_feedback:0.004201
# epochs: 85 5000/10000  deblurring stage :loss_deblur:0.042022
# epochs: 85 10000/10000  degradation modeling stage: loss_D:0.116246 , loss_G: 1.203550 loss_G_cycle:0.082478 loss_feedback:0.004191
# epochs: 85 10000/10000  deblurring stage :loss_deblur:0.041918
# epoch:86,learning_rate_D:3.125e-06
# epoch:86,learning_rate_G:3.125e-06
# epochs: 86 5000/10000  degradation modeling stage: loss_D:0.120773 , loss_G: 1.189547 loss_G_cycle:0.083275 loss_feedback:0.004220
# epochs: 86 5000/10000  deblurring stage :loss_deblur:0.042209
# epochs: 86 10000/10000  degradation modeling stage: loss_D:0.115964 , loss_G: 1.202378 loss_G_cycle:0.082739 loss_feedback:0.004197
# epochs: 86 10000/10000  deblurring stage :loss_deblur:0.041981
# epoch:87,learning_rate_D:3.125e-06
# epoch:87,learning_rate_G:3.125e-06
# epochs: 87 5000/10000  degradation modeling stage: loss_D:0.115862 , loss_G: 1.180304 loss_G_cycle:0.082581 loss_feedback:0.004200
# epochs: 87 5000/10000  deblurring stage :loss_deblur:0.042002
# epochs: 87 10000/10000  degradation modeling stage: loss_D:0.116330 , loss_G: 1.199146 loss_G_cycle:0.082632 loss_feedback:0.004198
# epochs: 87 10000/10000  deblurring stage :loss_deblur:0.041986
# epoch:88,learning_rate_D:3.125e-06
# epoch:88,learning_rate_G:3.125e-06
# epochs: 88 5000/10000  degradation modeling stage: loss_D:0.116036 , loss_G: 1.235116 loss_G_cycle:0.082452 loss_feedback:0.004183
# epochs: 88 5000/10000  deblurring stage :loss_deblur:0.041834
# epochs: 88 10000/10000  degradation modeling stage: loss_D:0.118847 , loss_G: 1.201525 loss_G_cycle:0.082694 loss_feedback:0.004205
# epochs: 88 10000/10000  deblurring stage :loss_deblur:0.042055
# epoch:89,learning_rate_D:3.125e-06
# epoch:89,learning_rate_G:3.125e-06
# epochs: 89 5000/10000  degradation modeling stage: loss_D:0.119107 , loss_G: 1.209446 loss_G_cycle:0.082733 loss_feedback:0.004193
# epochs: 89 5000/10000  deblurring stage :loss_deblur:0.041936
# epochs: 89 10000/10000  degradation modeling stage: loss_D:0.116704 , loss_G: 1.189674 loss_G_cycle:0.082445 loss_feedback:0.004200
# epochs: 89 10000/10000  deblurring stage :loss_deblur:0.042009
# epoch:90,learning_rate_D:1.5625e-06
# epoch:90,learning_rate_G:1.5625e-06
# epochs: 90 5000/10000  degradation modeling stage: loss_D:0.119945 , loss_G: 1.233216 loss_G_cycle:0.082106 loss_feedback:0.004173
# epochs: 90 5000/10000  deblurring stage :loss_deblur:0.041729
# epochs: 90 10000/10000  degradation modeling stage: loss_D:0.123219 , loss_G: 1.194327 loss_G_cycle:0.083306 loss_feedback:0.004214
# epochs: 90 10000/10000  deblurring stage :loss_deblur:0.042144
# epoch:91,learning_rate_D:1.5625e-06
# epoch:91,learning_rate_G:1.5625e-06
# epochs: 91 5000/10000  degradation modeling stage: loss_D:0.113196 , loss_G: 1.203537 loss_G_cycle:0.082001 loss_feedback:0.004187
# epochs: 91 5000/10000  deblurring stage :loss_deblur:0.041872
# epochs: 91 10000/10000  degradation modeling stage: loss_D:0.119940 , loss_G: 1.215935 loss_G_cycle:0.082678 loss_feedback:0.004190
# epochs: 91 10000/10000  deblurring stage :loss_deblur:0.041904
# epoch:92,learning_rate_D:1.5625e-06
# epoch:92,learning_rate_G:1.5625e-06
# epochs: 92 5000/10000  degradation modeling stage: loss_D:0.115269 , loss_G: 1.202301 loss_G_cycle:0.081936 loss_feedback:0.004191
# epochs: 92 5000/10000  deblurring stage :loss_deblur:0.041909
# epochs: 92 10000/10000  degradation modeling stage: loss_D:0.117273 , loss_G: 1.218712 loss_G_cycle:0.082658 loss_feedback:0.004185
# epochs: 92 10000/10000  deblurring stage :loss_deblur:0.041852
# epoch:93,learning_rate_D:1.5625e-06
# epoch:93,learning_rate_G:1.5625e-06
# epochs: 93 5000/10000  degradation modeling stage: loss_D:0.117666 , loss_G: 1.206807 loss_G_cycle:0.082314 loss_feedback:0.004198
# epochs: 93 5000/10000  deblurring stage :loss_deblur:0.041989
# epochs: 93 10000/10000  degradation modeling stage: loss_D:0.116047 , loss_G: 1.173435 loss_G_cycle:0.082872 loss_feedback:0.004190
# epochs: 93 10000/10000  deblurring stage :loss_deblur:0.041897
# epoch:94,learning_rate_D:1.5625e-06
# epoch:94,learning_rate_G:1.5625e-06
# epochs: 94 5000/10000  degradation modeling stage: loss_D:0.121043 , loss_G: 1.184863 loss_G_cycle:0.082710 loss_feedback:0.004198
# epochs: 94 5000/10000  deblurring stage :loss_deblur:0.041986
# epochs: 94 10000/10000  degradation modeling stage: loss_D:0.108292 , loss_G: 1.243292 loss_G_cycle:0.081758 loss_feedback:0.004185
# epochs: 94 10000/10000  deblurring stage :loss_deblur:0.041851
# epoch:95,learning_rate_D:1.5625e-06
# epoch:95,learning_rate_G:1.5625e-06
# epochs: 95 5000/10000  degradation modeling stage: loss_D:0.120357 , loss_G: 1.228918 loss_G_cycle:0.082698 loss_feedback:0.004199
# epochs: 95 5000/10000  deblurring stage :loss_deblur:0.041990
# epochs: 95 10000/10000  degradation modeling stage: loss_D:0.114560 , loss_G: 1.225684 loss_G_cycle:0.082084 loss_feedback:0.004189
# epochs: 95 10000/10000  deblurring stage :loss_deblur:0.041893
# epoch:96,learning_rate_D:1.5625e-06
# epoch:96,learning_rate_G:1.5625e-06
# epochs: 96 5000/10000  degradation modeling stage: loss_D:0.119558 , loss_G: 1.219534 loss_G_cycle:0.082484 loss_feedback:0.004196
# epochs: 96 5000/10000  deblurring stage :loss_deblur:0.041963
# epochs: 96 10000/10000  degradation modeling stage: loss_D:0.111459 , loss_G: 1.222670 loss_G_cycle:0.082200 loss_feedback:0.004191
# epochs: 96 10000/10000  deblurring stage :loss_deblur:0.041909
# epoch:97,learning_rate_D:1.5625e-06
# epoch:97,learning_rate_G:1.5625e-06
# epochs: 97 5000/10000  degradation modeling stage: loss_D:0.122338 , loss_G: 1.209122 loss_G_cycle:0.082486 loss_feedback:0.004206
# epochs: 97 5000/10000  deblurring stage :loss_deblur:0.042069
# epochs: 97 10000/10000  degradation modeling stage: loss_D:0.112937 , loss_G: 1.223369 loss_G_cycle:0.082014 loss_feedback:0.004177
# epochs: 97 10000/10000  deblurring stage :loss_deblur:0.041771
# epoch:98,learning_rate_D:1.5625e-06
# epoch:98,learning_rate_G:1.5625e-06
# epochs: 98 5000/10000  degradation modeling stage: loss_D:0.120698 , loss_G: 1.211999 loss_G_cycle:0.082493 loss_feedback:0.004190
# epochs: 98 5000/10000  deblurring stage :loss_deblur:0.041906
# epochs: 98 10000/10000  degradation modeling stage: loss_D:0.110415 , loss_G: 1.215695 loss_G_cycle:0.082144 loss_feedback:0.004194
# epochs: 98 10000/10000  deblurring stage :loss_deblur:0.041940
# epoch:99,learning_rate_D:1.5625e-06
# epoch:99,learning_rate_G:1.5625e-06
# epochs: 99 5000/10000  degradation modeling stage: loss_D:0.123635 , loss_G: 1.211778 loss_G_cycle:0.082705 loss_feedback:0.004201
# epochs: 99 5000/10000  deblurring stage :loss_deblur:0.042018
# epochs: 99 10000/10000  degradation modeling stage: loss_D:0.111499 , loss_G: 1.220778 loss_G_cycle:0.082505 loss_feedback:0.004189
# epochs: 99 10000/10000  deblurring stage :loss_deblur:0.041893
# epoch:100,learning_rate_D:1.5625e-06
# epoch:100,learning_rate_G:1.5625e-06
# epochs: 100 5000/10000  degradation modeling stage: loss_D:0.115882 , loss_G: 1.226197 loss_G_cycle:0.082613 loss_feedback:0.004197
# epochs: 100 5000/10000  deblurring stage :loss_deblur:0.041972
# epochs: 100 10000/10000  degradation modeling stage: loss_D:0.114408 , loss_G: 1.221458 loss_G_cycle:0.082298 loss_feedback:0.004194
# epochs: 100 10000/10000  deblurring stage :loss_deblur:0.041940
# done training!
