# %%
from utils.generate_images import simulate_images

# %% [markdown]
# # Input Parameters

# %%
# Basic parameters
scr_dir  = r'D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\Ground Truth\Nuclei/'  # Path to your training data
psf_path = r'D:\Current_Segovia_lab\Deconvolution_Dilan\data\PSF/PSF_far_red_647.tif'                 # Path to your point spread function (PSF) file PSF_Green_488, PSF_Red_568, PSF_far_red_647
out_dir  = r'D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_Jupyter\Raw 3D\Nuclei\test/'     # Output directory for augmented data
snr_targets = [1, 5, 15]         # Desired signal-to-noise ratiossdezx
conv_type = '3D'   # 2D or 3D deconvolution

# %%
# Advanced parameters
background_level = 0.1          # Percentage of intensity added as background (0 to 1)
local_variation_scale = 5       # Scale for local intensity variations (uneven staining)
z_decay_rate = 0.9975           # Z-stack dependent intensity decay (axial intensity variation)
std_dev = 10.00                 # Initial guess for Gaussian noise standard deviation

# %% [markdown]
# # Create simulated images

# %%
simulate_images(
    scr_dir = scr_dir,
    psf_path = psf_path, 
    out_dir = out_dir,
    snr_targets = snr_targets,
    background_level = background_level,
    local_variation_scale = local_variation_scale,
    z_decay_rate = z_decay_rate,
    std_dev = std_dev,
    conv_type = '3D'
)
# Out:
# PSF Loaded: D:\Current_Segovia_lab\Deconvolution_Dilan\data\PSF/PSF_far_red_647.tif
# Processing file: D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\Ground Truth\Nuclei/masks\Nuclei_GT_Ch3_Mask.tif
# PSF is not normalized. Normalizing now. Sum of PSF = 55.02137756347656
# Iterations:   7%|██▏                             | 14/200 [04:32<1:00:23, 19.48s/iteration, SNR=16.28, std_dev=37.9750]
#  Final SNR: 14.97 (Target SNR: 15), Gaussian std_dev: 37.9750, Iterations: 14
# Iterations:   7%|██▏                             | 14/200 [04:47<1:03:33, 20.50s/iteration, SNR=5.39, std_dev=144.2099]
#  Final SNR: 5.00 (Target SNR: 5), Gaussian std_dev: 144.2099, Iterations: 14
# Iterations:  10%|███                             | 19/200 [06:45<1:04:27, 21.37s/iteration, SNR=1.15, std_dev=881.9749]
#  Final SNR: 1.05 (Target SNR: 1), Gaussian std_dev: 881.9749, Iterations: 19
# ...

# %%
print("All calculations are successfully finished")
# Out:
# All calculations are successfully finished
