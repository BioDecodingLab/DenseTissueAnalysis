# %%
from utils.generate_images import simulate_images

# %% [markdown]
# # Input Parameters

# %%
# Basic parameters
scr_dir  = r'D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\Ground Truth\Membranes/'  # Path to your training data
psf_path = r'D:\Current_Segovia_lab\Deconvolution_Dilan\data\PSF/PSF_Green_488.tif'                 # Path to your point spread function (PSF) file
out_dir  = r'D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_Jupyter\Isotropic/Membranes/'     # Output directory for augmented data
snr_targets = [15]         # Desired signal-to-noise ratiossdezx
conv_type = '2D'   # 2D or 3D deconvolution

# %%
# Advanced parameters
background_level = 0.1          # Percentage of intensity added as background (0 to 1)
local_variation_scale = 5       # Scale for local intensity variations (uneven staining)
z_decay_rate = 0.9975           # Z-stack dependent intensity decay (axial intensity variation)
std_dev = 10.00                 # Initial guess for Gaussian noise standard deviation

# %% [markdown]
# # Create simulated images

# %%
simulate_images(
    scr_dir = scr_dir,
    psf_path = psf_path, 
    out_dir = out_dir,
    snr_targets = snr_targets,
    background_level = background_level,
    local_variation_scale = local_variation_scale,
    z_decay_rate = z_decay_rate,
    std_dev = std_dev,
    conv_type = '2D'
)
# Out:
# PSF Loaded: D:\Current_Segovia_lab\Deconvolution_Dilan\data\PSF/PSF_Green_488.tif
# Processing file: D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\Ground Truth\Membranes/masks\Membrane_GT_Ch2.tif
# PSF is not normalized. Normalizing now. Sum of PSF = 60.5782585144043
# Iterations:  76%|██████████████████████████        | 153/200 [45:41<14:02, 17.92s/iteration, SNR=12.04, std_dev=0.0000]
#  Final SNR: 12.04 (Target SNR: 15), Gaussian std_dev: 0.0000, Iterations: 153
# Processing file: D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\Ground Truth\Membranes/masks\Membrane_GT_Ch3.tif
# PSF is already normalized. Sum of PSF = 1.0
# Iterations:  76%|██████████████████████████        | 153/200 [46:35<14:18, 18.27s/iteration, SNR=12.45, std_dev=0.0000]
#  Final SNR: 12.45 (Target SNR: 15), Gaussian std_dev: 0.0000, Iterations: 153
# Processing file: D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\Ground Truth\Membranes/masks\Membrane_GT_G1.tif
# PSF is already normalized. Sum of PSF = 1.0
# Iterations:  76%|██████████████████████████        | 153/200 [40:06<12:19, 15.73s/iteration, SNR=12.55, std_dev=0.0000]
#  Final SNR: 12.55 (Target SNR: 15), Gaussian std_dev: 0.0000, Iterations: 153
# Processing file: D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\Ground Truth\Membranes/masks\Membrane_GT_G2.tif
# PSF is already normalized. Sum of PSF = 1.0
# Iterations:  76%|██████████████████████████        | 153/200 [43:16<13:17, 16.97s/iteration, SNR=12.24, std_dev=0.0000]
#  Final SNR: 12.24 (Target SNR: 15), Gaussian std_dev: 0.0000, Iterations: 153

# %%
print("All calculations are successfully finished")
# Out:
# All calculations are successfully finished
