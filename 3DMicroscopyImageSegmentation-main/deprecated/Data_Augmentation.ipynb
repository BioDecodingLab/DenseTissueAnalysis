# %%
from utils.generate_images import simulate_images

# %% [markdown]
# # Input Parameters

# %%
# Basic parameters
scr_dir  = r'D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\test/a/'  # Path to your training data
psf_path = r'D:\Current_Segovia_lab\Deconvolution_Dilan\data\PSF/PSF_far_red_647.tif'   # Path to your point spread function (PSF) file
out_dir  = r'D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\test/result/'     # Output directory for augmented data
snr_targets = [15, 10, 5, 4, 3, 2, 1]         # Desired signal-to-noise ratiossdezx

# %%
# Advanced parameters
background_level = 0.1          # Percentage of intensity added as background (0 to 1)
local_variation_scale = 5       # Scale for local intensity variations (uneven staining)
z_decay_rate = 0.9975           # Z-stack dependent intensity decay (axial intensity variation)
std_dev = 10.00                 # Initial guess for Gaussian noise standard deviation

# %% [markdown]
# # Create simulated images

# %%
simulate_images(
    scr_dir = scr_dir,
    psf_path = psf_path, 
    out_dir = out_dir,
    snr_targets = snr_targets,
    background_level = background_level,
    local_variation_scale = local_variation_scale,
    z_decay_rate = z_decay_rate,
    std_dev = std_dev
)
# Out:
# PSF Loaded: D:\Current_Segovia_lab\Deconvolution_Dilan\data\PSF/PSF_far_red_647.tif
# Processing file: D:\Current_Segovia_lab\Deconvolution_Dilan\data\Synthetic_images_MT\test/a/masks\Nuclei_GT_Ch2.tif
# PSF is not normalized. Normalizing now. Sum of PSF = 55.02137756347656
# Iterations:   8%|██▋                               | 16/200 [04:42<54:10, 17.67s/iteration, SNR=16.32, std_dev=37.5952]
#  Final SNR: 15.00 (Target SNR: 15), Gaussian std_dev: 37.5952, Iterations: 16
# Iterations:   2%|▊                                | 5/200 [01:46<1:09:31, 21.39s/iteration, SNR=10.75, std_dev=60.5475]
#  Final SNR: 9.92 (Target SNR: 10), Gaussian std_dev: 60.5475, Iterations: 5
# Iterations:   4%|█▍                               | 9/200 [03:02<1:04:23, 20.23s/iteration, SNR=5.39, std_dev=142.7678]
#  Final SNR: 5.00 (Target SNR: 5), Gaussian std_dev: 142.7678, Iterations: 9
# Iterations:   2%|▍                                | 3/200 [01:20<1:27:53, 26.77s/iteration, SNR=4.29, std_dev=190.0240]
#  Final SNR: 3.97 (Target SNR: 4), Gaussian std_dev: 190.0240, Iterations: 3
# Iterations:   3%|▉                                | 6/200 [02:16<1:13:21, 22.69s/iteration, SNR=3.16, std_dev=275.4320]
#  Final SNR: 2.91 (Target SNR: 3), Gaussian std_dev: 275.4320, Iterations: 6
# Iterations:   2%|▊                                | 5/200 [01:59<1:17:29, 23.85s/iteration, SNR=2.10, std_dev=443.5860]
#  Final SNR: 1.94 (Target SNR: 2), Gaussian std_dev: 443.5860, Iterations: 5
# Iterations:   4%|█▏                               | 7/200 [02:39<1:13:15, 22.77s/iteration, SNR=1.16, std_dev=864.4236]
#  Final SNR: 1.06 (Target SNR: 1), Gaussian std_dev: 864.4236, Iterations: 7

# %%
print("All calculations are successfully finished")
# Out:
# All calculations are successfully finished
